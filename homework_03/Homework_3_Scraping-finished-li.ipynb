# %% [markdown]
# ## Homework 3: Scraping
# This homework asks you to scrape from three different sources, please follow the instructions and do the best you can. With the exception of the first cell that imports the request and the beautiful soup library, I have not pre-written any code for you. Do not be afraid--you may look at the tutorial for examples, as well as the Beautiful Soup documentation, and any other Python resource (such a Stack overflow) if need be.
#
# This homework is intended to be challenging, if you only get 70% of the stuff done that's great!

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Shakespeare
# I've posted some relatively simple HTML of the first act of William Shakespeare's The Tempest here: http://floatingmedia.com/columbia/tempest.html please use that URL to download the HTML and put it through Beautiful Soup. (It also may be very helpful for you to go to that page in chrome and inspect elements why you do this.)
# **Please note: there are 2 scenes in Act 1**

# %% [markdown]
# In the cells below you should you make two lines--a variable that requests and reads the HTML from the URL (http://floatingmedia.com/columbia/tempest.html), and a second variable that passes the raw HTML into Beautiful Soup. You will use that beautiful soup variable to search the HTML.

# %%
raw_html = requests.get("http://floatingmedia.com/columbia/tempest.html").content
play = BeautifulSoup(raw_html, "html.parser")
print(type(play))
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# Get the title of the play:

# %%
play.head.title.string
# Out:
# 'The Tempest'

# %% [markdown]
# Get the HTML that contains the setting of Act One Scene 1:

# %%
play.body.find("strong")
# Out:
# <strong>
# On a ship at sea</strong>

# %% [markdown]
# Get the setting of Act One Scene 1 (without HTML tags):

# %%
play.body.find("strong").string
# Out:
# '\nOn a ship at sea'

# %% [markdown]
# Get the setting of scene 2

# %%
play.body.find_all("div")[2].strong.string
# Out:
# 'The island. Before PROSPERO’S cell.'

# %% [markdown]
# Get the name of the first character in Scene 1

# %%
play.body.find_all("div")[1].find("strong").string
# Out:
# 'Master. '

# %% [markdown]
# Get a list of all of characters in Scene 1 (repeats are fine, you need a loop here)

# %%
names_scene1 = play.body.find_all("div")[1].find_all("strong")

for name in names_scene1:
    print(name.string)
# Out:
# Master.
# Boatswain.
# Master.
# Boatswain.
# Alonso.
# Boatswain.
# Antonio.
# Boatswain.
# Gonzalo.
# Boatswain.
# Gonzalo.
# Boatswain.
# Gonzalo.
# Boatswain.
# Sebastian.
# Boatswain.
# Antonio.
# Gonzalo.
# Boatswain.
# Mariners.
# Boatswain.
# Gonzalo.
# Sebastian.
# Antonio.
# Gonzalo.
# Antonio.
# Sebastian.
# Gonzalo.

# %% [markdown]
# **Bonus:** write a script that takes all the duplicates out of the list. (This is a python thing, not a beautiful soup thing.)

# %%
names_scene1 = play.body.find_all("div")[1].find_all("strong")
name_clean = []

for name in names_scene1:
    if name.string not in name_clean:
        name_clean.append(name.string)
        
print("Here are all the characters in Scene 1:", name_clean)
# Out:
# Here are all the characters in Scene 1: ['Master. ', 'Boatswain. ', 'Alonso. ', 'Antonio. ', 'Gonzalo. ', 'Sebastian. ', 'Mariners. ']

# %% [markdown]
# Display every stage direction in _scene 2_

# %%
dirs_scene2 = play.body.find_all("div")[3].find_all("p", attrs={"class": "stagedir"})

for dir_scene2 in dirs_scene2:
    print(dir_scene2.string)
# Out:
# [Enter PROSPERO and MIRANDA]
# [Enter ARIEL]
# [Exit]
# [Enter CALIBAN]
# [Draws, and is charmed from moving]
# [Exeunt]

# %% [markdown]
# Get the HTML containing Miranda's first speech in Scene 2

# %%
play.body.find_all("div")[3].ul.li
# Out:
# <li class="playtext"><strong>Miranda. </strong>If by your art, my dearest father, you have
#  <span class="playlinenum">85</span><br/>Put the wild waters in this roar, allay them.
# <br/>The sky, it seems, would pour down stinking pitch,
# <br/>But that the sea, mounting to the welkin's cheek,
# <br/>Dashes the fire out. O, I have suffered
# <br/>With those that I saw suffer: a brave vessel,
#  <span class="playlinenum">90</span><br/>Who had, no doubt, some noble creature in her,
# <br/>Dash'd all to pieces. O, the cry did knock
# <br/>Against my very heart. Poor souls, they perish'd.
# <br/>Had I been any god of power, I would
# <br/>Have sunk the sea within the earth or ere
#  <span class="playlinenum">95</span><br/>It should the good ship so have swallow'd and
# <br/>The fraughting souls within her.
# </li>

# %% [markdown]
# Now display those **same lines without the speaker's name, and no HTML.**
#
# This is a bit tricky, try to get as close to this result as you can. (Note: I didn't get the numbers out of there, but it's fine if you want to get them out too):
#
# `If by your art, my dearest father, you have
#
# 85
# Put the wild waters in this roar, allay them.
#
# The sky, it seems, would pour down stinking pitch,
#
# But that the sea, mounting to the welkin's cheek,
#
# Dashes the fire out. O, I have suffered
#
# With those that I saw suffer: a brave vessel,
#
# 90
# Who had, no doubt, some noble creature in her,
#
# Dash'd all to pieces. O, the cry did knock
#
# Against my very heart. Poor souls, they perish'd.
#
# Had I been any god of power, I would
#
# Have sunk the sea within the earth or ere
#
# 95
# It should the good ship so have swallow'd and
#
# The fraughting souls within her.`

# %%
brs = play.body.find_all("div")[3].ul.li.find_all("br")
first_line = play.body.find_all("div")[3].ul.li.strong.next_sibling
last_line = play.body.find_all("div")[3].ul.li.find_all("br")[-1].next

print(first_line)
for br in brs:
    print(br.previous)
print(last_line)
# Out:
# If by your art, my dearest father, you have
#
# 85
# Put the wild waters in this roar, allay them.
#
# The sky, it seems, would pour down stinking pitch,
#
# But that the sea, mounting to the welkin's cheek,
#
# Dashes the fire out. O, I have suffered
#
# 90
# Who had, no doubt, some noble creature in her,
#
# Dash'd all to pieces. O, the cry did knock
#
# Against my very heart. Poor souls, they perish'd.
#
# Had I been any god of power, I would
#
# 95
# It should the good ship so have swallow'd and
#
# The fraughting souls within her.

# %% [markdown]
# Get the HTML containing the speech after Miranda's

# %%
play.body.find_all("div")[3].find_all("ul")[1]
# Out:
# <ul><li class="playtext"><strong>Prospero. </strong>Be collected:
# <br/>No more amazement: tell your piteous heart
# <br/>There's no harm done.
#  <span class="playlinenum">100</span></li></ul>

# %% [markdown]
# ## Supreme Court Decisions 2017
# Okay now it's time to scrape from reality. The Supreme Court posts its decisions in a format that is not particularly data friendly. They have a simple HTML table with some information about the decision, including a link to a PDF that contains the written decision. We won't mess with those PDFs this week, but we do want to transform their tables into something useful to us.
#
# We will be scraping this page:
# https://www.supremecourt.gov/opinions/slipopinion/17
#
# *Note:* While you won't see all of the tables for all the months when you go to the page, they are all there in the HTML that you will download and in the HTML source (which is the same thing). Definitely do a view source, and study the structure of the HTML tables before you start coding.
#
# You eventually want to end up with a list of lists (rows and then columns) for every decision from the 2017. Follow the process, and see how far you get.

# %% [markdown]
# Once again, Write your lines that use requests to get the page, and a second variable that passes the raw HTML into Beautiful Soup for parsing. Include a third line that prints the HTML in the prettify() way.

# %%
raw_html = requests.get("https://www.supremecourt.gov/opinions/slipopinion/17").content
sc = BeautifulSoup(raw_html, "html.parser")
print(type(sc))
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# Isolate the HTML row with the first row of information for the case Azar v. Garza

# %%
sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")[1]
# Out:
# <tr>
# <td style="text-align: center;">46</td>
# <td style="text-align: center;">6/04/18</td>
# <td style="text-align: center;">17-654</td>
# <td><a href="/opinions/17pdf/17-654_5j3b.pdf" target="_blank" title="The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.">Azar v. Garza</a></td>
# <td style="text-align: center;"> </td>
# <td style="text-align: center;">PC</td>
# <td style="text-align: center;">584/2</td>
# </tr>

# %% [markdown]
# Print out each cell of information from that first row. Your output should look like this:
#
#
# ```
# 46
# 6/04/18
# 17-654
# Azar v. Garza
#
# PC
# 584/2
# ```

# %%
first_row = sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")[1].find_all("td")
for line in first_row:
    print(line.string)
# Out:
# 46
# 6/04/18
# 17-654
# Azar v. Garza
#
# PC
# 584/2

# %% [markdown]
# But wait, there is more information hidden inside the tags! Really important information. Find it and print it out like this (still just for this first row):
# ```
# /opinions/17pdf/17-654_5j3b.pdf
#  The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.
#  ```

# %%
link = sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")[1].find_all("a")[0]['href']
comment = sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")[1].find_all("a")[0]['title']

print(link)
print(comment)
# Out:
# /opinions/17pdf/17-654_5j3b.pdf
# The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.

# %% [markdown]
# Okay, time to make this useful. Take the information you printed in the last two cells, and combine them all into a list. Output the list, it should look like this:
# ```
# ['46',
#  '6/04/18',
#  '17-654',
#  'Azar v. Garza',
#  '\xa0',
#  'PC',
#  '584/2',
#  '/opinions/17pdf/17-654_5j3b.pdf',
#  'The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.']
#  ```

# %%
first_row = sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")[1].find_all("td")
link = sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")[1].find_all("a")[0]['href']
comment = sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")[1].find_all("a")[0]['title']

table = []
for line in first_row:
    table.append(line.string)

table.append(link)
table.append(comment)
table
# Out:
# ['46',
#  '6/04/18',
#  '17-654',
#  'Azar v. Garza',
#  '\xa0',
#  'PC',
#  '584/2',
#  '/opinions/17pdf/17-654_5j3b.pdf',
#  'The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.']

# %% [markdown]
# Great! Now you want to go through all of the rows in that first table (but not the header), and get a list of lists with the information for every case in that row. Your output should look like this:
#
# ```
# [['46',
#   '6/04/18',
#   '17-654',
#   'Azar v. Garza',
#   '\xa0',
#   'PC',
#   '584/2',
#   '/opinions/17pdf/17-654_5j3b.pdf',
#   'The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.'],
#  ['45',
#   '6/04/18',
#   '16-1215',
#   'Lamar, Archer & Cofrin, LLP v. Appling',
#   '\xa0',
#   'SS',
#   '584/2',
#   '/opinions/17pdf/16-1215_gdhk.pdf',
#   'Single-asset statements qualify as “statement[s] respecting the debtor’s . . . financial condition” for purposes of Bankruptcy Code §523(a)(2)’s exceptions to discharge; where, as here, a single-asset statement is not in writing, the associated debt may be discharged.'],
#  ['44',
#   '6/04/18',
#   '17-5716',
#   'Koons v. United States',
#   '\xa0',
#   'A',
#   '584/2',
#   '/opinions/17pdf/17-5716_jhek.pdf',
#   'Petitioners do not qualify for sentence reductions under 18 U. S. C. §3582(c)(2) because their sentences were not “based on” their lowered Federal Sentencing Guidelines ranges but, instead, were “based on” their mandatory minimums and their substantial assistance to the Government.'],
#  ['43',
#   '6/04/18',
#   '17-155',
#   'Hughes v. United States',
#   '6/05/18',
#   'K',
#   '584/2',
#   '/opinions/17pdf/17-155_new_4f15.pdf',
#   'A Federal Rule of Criminal Procedure 11(c)(1)(C) plea agreement is “based on” the defendant’s Federal Sentencing Guidelines range so long as that range was part of the framework the district court relied on in imposing the sentence or accepting the agreement; thus, Hughes may seek a sentencing reduction under 18 U. S. C. §3582(c)(2).'],
#  ['42',
#   '6/04/18',
#   '16-111',
#   'Masterpiece Cakeshop, Ltd. v. Colorado Civil Rights Comm’n',
#   '6/04/18',
#   'K',
#   '584/2',
#   '/opinions/17pdf/16-111_new_d1of.pdf',
#   'The Colorado Civil Rights Commission’s actions in assessing a cakeshop owner’s reasons for declining to make a cake for a same-sex couple’s wedding celebration violated the Free Exercise Clause.']]
# ```

# %%
table = sc.body.find("div", attrs={"id":"cell6"}).find_all("tr")
final_list = []
for rows in table[1:]:
    first_row = []
    tds = rows.find_all("td")
    for td in tds:
        first_row.append(td.string)
    
    link = rows.find_all("a")[0]['href']
    comment = rows.find_all("a")[0]['title']
    first_row.append(link)
    first_row.append(comment)
    
    final_list.append(first_row)
 
print(final_list)
# Out:
# [['46', '6/04/18', '17-654', 'Azar v. Garza', '\xa0', 'PC', '584/2', '/opinions/17pdf/17-654_5j3b.pdf', 'The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.'], ['45', '6/04/18', '16-1215', 'Lamar, Archer & Cofrin, LLP v. Appling', '\xa0', 'SS', '584/2', '/opinions/17pdf/16-1215_gdhk.pdf', 'Single-asset statements qualify as “statement[s] respecting the debtor’s . . . financial condition” for purposes of Bankruptcy Code §523(a)(2)’s exceptions to discharge; where, as here, a single-asset statement is not in writing, the associated debt may be discharged.'], ['44', '6/04/18', '17-5716', 'Koons v. United States', '\xa0', 'A', '584/2', '/opinions/17pdf/17-5716_jhek.pdf', 'Petitioners do not qualify for sentence reductions under 18 U. S. C. §3582(c)(2) because their sentences were not “based on” their lowered Federal Sentencing Guidelines ranges but, instead, were “based on” their mandatory minimums and their substantial assistance to the Government.'], ['43', '6/04/18', '17-155', 'Hughes v. United States', '6/05/18', 'K', '584/2', '/opinions/17pdf/17-155_new_4f15.pdf', 'A Federal Rule of Criminal Procedure 11(c)(1)(C) plea agreement is “based on” the defendant’s Federal Sentencing Guidelines range so long as that range was part of the framework the district court relied on in imposing the sentence or accepting the agreement; thus, Hughes may seek a sentencing reduction under 18 U. S. C. §3582(c)(2).'], ['42', '6/04/18', '16-111', 'Masterpiece Cakeshop, Ltd. v. Colorado Civil Rights Comm’n', '6/04/18', 'K', '584/2', '/opinions/17pdf/16-111_new_d1of.pdf', 'The Colorado Civil Rights Commission’s actions in assessing a cakeshop owner’s reasons for declining to make a cake for a same-sex couple’s wedding celebration violated the Free Exercise Clause.']]

# %% [markdown]
# Finally, go through EVERY table, and get out every row--no headers. So you have all of the 2017 decisions from 46-1 info in excellent list within list format.

# %%
tables = sc.body.find_all("div", attrs={"class":"alt-table-responsive"})
final_table = []
for table in tables:
    final_list = []
    month = table.find_all("tr")
    
    for rows in month[1:]:
        first_row = []
        tds = rows.find_all("td")
        for td in tds:
            first_row.append(td.string)
    
        link = rows.find_all("a")[0]['href']
        comment = rows.find_all("a")[0]['title']
        first_row.append(link)
        first_row.append(comment)
    
        final_list.append(first_row)
        
    final_table.append(final_list)

print(final_table)

#MAGIC!
# Out:
# [[['46', '6/04/18', '17-654', 'Azar v. Garza', '\xa0', 'PC', '584/2', '/opinions/17pdf/17-654_5j3b.pdf', 'The D. C. Circuit’s judgment is vacated, and the case is remanded with instructions to dismiss the individual claim for injunctive relief as moot.'], ['45', '6/04/18', '16-1215', 'Lamar, Archer & Cofrin, LLP v. Appling', '\xa0', 'SS', '584/2', '/opinions/17pdf/16-1215_gdhk.pdf', 'Single-asset statements qualify as “statement[s] respecting the debtor’s . . . financial condition” for purposes of Bankruptcy Code §523(a)(2)’s exceptions to discharge; where, as here, a single-asset statement is not in writing, the associated debt may be discharged.'], ['44', '6/04/18', '17-5716', 'Koons v. United States', '\xa0', 'A', '584/2', '/opinions/17pdf/17-5716_jhek.pdf', 'Petitioners do not qualify for sentence reductions under 18 U. S. C. §3582(c)(2) because their sentences were not “based on” their lowered Federal Sentencing Guidelines ranges but, instead, were “based on” their mandatory minimums and their substantial assistance to the Government.'], ['43', '6/04/18', '17-155', 'Hughes v. United States', '6/05/18', 'K', '584/2', '/opinions/17pdf/17-155_new_4f15.pdf', 'A Federal Rule of Criminal Procedure 11(c)(1)(C) plea agreement is “based on” the defendant’s Federal Sentencing Guidelines range so long as that range was part of the framework the district court relied on in imposing the sentence or accepting the agreement; thus, Hughes may seek a sentencing reduction under 18 U. S. C. §3582(c)(2).'], ['42', '6/04/18', '16-111', 'Masterpiece Cakeshop, Ltd. v. Colorado Civil Rights Comm’n', '6/04/18', 'K', '584/2', '/opinions/17pdf/16-111_new_d1of.pdf', 'The Colorado Civil Rights Commission’s actions in assessing a cakeshop owner’s reasons for declining to make a cake for a same-sex couple’s wedding celebration violated the Free Exercise Clause.']], [['41', '5/29/18', '16-1495', 'City of Hays v. Vogt', '\xa0', 'PC', '584/2', '/opinions/17pdf/16-1495_e1pf.pdf', ' Certiorari dismissed as improvidently granted.'], ['40', '5/29/18', '16-1027', 'Collins v. Virginia', '\xa0', 'SS', '584/2', '/opinions/17pdf/16-1027_7lio.pdf', ' The Fourth Amendment’s automobile exception does not permit the warrantless entry of a home or its curtilage in order to search a vehicle therein.'], ['39', '5/29/18', '16-1519', 'Lagos v. United States', '\xa0', 'B', '584/2', '/opinions/17pdf/16-1519_o7jp.pdf', ' In a provision of the Mandatory Victims Restitution Act of 1996 that requires certain convicted defendants to “reimburse the victim for . . . expenses incurred during participation in the investigation or prosecution of the offense or attendance at proceedings related to the offense,” 18 U. S. C. §3663A(b)(4), the words “investigation” and “proceedings” are limited to government investigations and criminal proceedings and do not include private investigations and civil or bankruptcy proceedings.'], ['38', '5/21/18', '17-387', 'Upper Skagit Tribe v. Lundgren', '\xa0', 'NG', '584/2', '/opinions/17pdf/17-387_ap6c.pdf', ' County of Yakima v. Confederated Tribes and Bands of Yakima Nation, 502 U. S. 251, addressed only a question of statutory interpretation of the Indian General Allotment Act of 1887, not the question whether Indian tribes have sovereign immunity in in rem lawsuits.'], ['37', '5/21/18', '16-285', 'Epic Systems Corp. v. Lewis', '\xa0', 'NG', '584/2', '/opinions/17pdf/16-285_q8l1.pdf', ' Congress has instructed in the Federal Arbitration Act that arbitration agreements providing for individualized proceedings must be enforced, and neither the Arbitration Act’s saving clause nor the National Labor Relations Act suggests otherwise.'], ['36', '5/14/18', '16-476', 'Murphy v. National Collegiate Athletic Assn.', '\xa0', 'A', '584/2', '/opinions/17pdf/16-476_dbfi.pdf', ' Professional and Amateur Sports Protection Act (PASPA) provisions that prohibit state authorization and licensing of sports gambling schemes, see 28 U. S. C. §3702(1), violate the Constit ...

# %% [markdown]
# ## Real Shakespeare: Extra Credit
# The Folger  Shakespeare Library has HTML versions of their Shakespeare publicly available, but in terrible HTML format. If you want to challenge yourself try pulling out the first 100 lines of Twelfth Night, available here:
#
# http://floatingmedia.com/columbia/FolgerShakes/TN.html
#
# The final output should resemble what you see below. Each of these lines contains three elements:
#
# 1) a code for act.scene.line Along with whether is the stage direction
# 2) the speaker or the last person who spoke prior to the stage direction
# 3) a line or stage direction.
#
# `
# line-SD 1.1.0	NOSPEAKER	Enter Orsino, Duke of Illyria, Curio, and other Lords,
# line-SD 1.1.0	NOSPEAKER	with
# line-SD 1.1.0	NOSPEAKER	 Musicians playing.
# line-1.1.1	ORSINO	If music be the food of love, play on.
# line-1.1.2	ORSINO	Give me excess of it, that, surfeiting,
# line-1.1.3	ORSINO	The appetite may sicken and so die.
# line-1.1.4	ORSINO	That strain again! It had a dying fall.
# line-1.1.5	ORSINO	O, it came o’er my ear like the sweet sound
# line-1.1.6	ORSINO	That breathes upon a bank of violets,
# line-1.1.7	ORSINO	Stealing and giving odor. Enough; no more.
# line-1.1.8	ORSINO	’Tis not so sweet now as it was before.
# line-1.1.9	ORSINO	O spirit of love, how quick and fresh art thou,
# line-1.1.10	ORSINO	That, notwithstanding thy capacity
# line-1.1.11	ORSINO	Receiveth as the sea, naught enters there,
# line-1.1.12	ORSINO	Of what validity and pitch soe’er,
# line-1.1.13	ORSINO	But falls into abatement and low price
# line-1.1.14	ORSINO	Even in a minute. So full of shapes is fancy
# line-1.1.15	ORSINO	That it alone is high fantastical.
# line-1.1.16	CURIO	Will you go hunt, my lord?
# line-1.1.17	ORSINO	What, Curio?
# line-1.1.18	CURIO	The hart.
# line-1.1.19	ORSINO	Why, so I do, the noblest that I have.
# line-1.1.20	ORSINO	O, when mine eyes did see Olivia first,
# line-1.1.21	ORSINO	Methought she purged the air of pestilence.
# line-1.1.22	ORSINO	That instant was I turned into a hart,
# line-1.1.23	ORSINO	And my desires, like fell and cruel hounds,
# line-1.1.24	ORSINO	E’er since pursue me.
# line-SD 1.1.24.1	ORSINO	Enter Valentine.
# line-1.1.25	ORSINO	How now, what news from her?
# line-1.1.26	VALENTINE	So please my lord, I might not be admitted,
# line-1.1.27	VALENTINE	But from her handmaid do return this answer:
# line-1.1.28	VALENTINE	The element itself, till seven years’ heat,
# line-1.1.29	VALENTINE	Shall not behold her face at ample view,
# line-1.1.30	VALENTINE	But like a cloistress she will veilèd walk,
# line-1.1.31	VALENTINE	And water once a day her chamber round
# line-1.1.32	VALENTINE	With eye-offending brine—all this to season
# line-1.1.33	VALENTINE	A brother’s dead love, which she would keep fresh
# line-1.1.34	VALENTINE	And lasting in her sad remembrance.
# line-1.1.35	ORSINO	O, she that hath a heart of that fine frame
# line-1.1.36	ORSINO	To pay this debt of love but to a brother,
# line-1.1.37	ORSINO	How will she love when the rich golden shaft
# line-1.1.38	ORSINO	Hath killed the flock of all affections else
# line-1.1.39	ORSINO	That live in her; when liver, brain, and heart,
# line-1.1.40	ORSINO	These sovereign thrones, are all supplied, and filled
# line-1.1.41	ORSINO	Her sweet perfections with one self king!
# line-1.1.42	ORSINO	Away before me to sweet beds of flowers!
# line-1.1.43	ORSINO	Love thoughts lie rich when canopied with bowers.
# line-SD 1.1.43.1	ORSINO	They exit.
# line-SD 1.2.0	ORSINO	Enter Viola, a Captain, and Sailors.
# line-1.2.1	VIOLA	What country, friends, is this?
# line-1.2.2	CAPTAIN	This is Illyria, lady.
# line-1.2.3	VIOLA	And what should I do in Illyria?
# line-1.2.4	VIOLA	My brother he is in Elysium.
# line-1.2.5	VIOLA	Perchance he is not drowned.—What think you,
# line-1.2.6	VIOLA	sailors?
# line-1.2.7	CAPTAIN	It is perchance that you yourself were saved.
# line-1.2.8	VIOLA	O, my poor brother! And so perchance may he be.
# line-1.2.9	CAPTAIN	True, madam. And to comfort you with chance,
# line-1.2.10	CAPTAIN	Assure yourself, after our ship did split,
# line-1.2.11	CAPTAIN	When you and those poor number saved with you
# line-1.2.12	CAPTAIN	Hung on our driving boat, I saw your brother,
# line-1.2.13	CAPTAIN	Most provident in peril, bind himself
# line-1.2.14	CAPTAIN	(Courage and hope both teaching him the practice)
# line-1.2.15	CAPTAIN	To a strong mast that lived upon the sea,
# line-1.2.16	CAPTAIN	Where, like Arion
# line-1.2.16	CAPTAIN	 on the dolphin’s back,
# line-1.2.17	CAPTAIN	I saw him hold acquaintance with the waves
# line-1.2.18	CAPTAIN	So long as I could see.
# line-SD 1.2.19	VIOLA	, giving
# line-SD 1.2.19	VIOLA	 him money
# line-1.2.19	VIOLA	For saying so, there’s gold.
# line-1.2.20	VIOLA	Mine own escape unfoldeth to my hope,
# line-1.2.21	VIOLA	Whereto thy speech serves for authority,
# line-1.2.22	VIOLA	The like of him. Know’st thou this country?
# line-1.2.23	CAPTAIN	Ay, madam, well, for I was bred and born
# line-1.2.24	CAPTAIN	Not three hours’ travel from this very place.
# line-1.2.25	VIOLA	Who governs here?
# line-1.2.26	CAPTAIN	A noble duke, in nature as in name.
# line-1.2.27	VIOLA	What is his name?
# line-1.2.28	CAPTAIN	Orsino.
# line-1.2.29	VIOLA	Orsino. I have heard my father name him.
# line-1.2.30	VIOLA	He was a bachelor then.
# line-1.2.31	CAPTAIN	And so is now, or was so very late;
# line-1.2.32	CAPTAIN	For but a month ago I went from hence,
# line-1.2.33	CAPTAIN	And then ’twas fresh in murmur (as, you know,
# line-1.2.34	CAPTAIN	What great ones do the less will prattle of)
# line-1.2.35	CAPTAIN	That he did seek the love of fair Olivia.
# line-1.2.36	VIOLA	What’s she?
# line-1.2.37	CAPTAIN	A virtuous maid, the daughter of a count
# line-1.2.38	CAPTAIN	That died some twelvemonth since, then leaving her
# line-1.2.39	CAPTAIN	In the protection of his son, her brother,
# line-1.2.40	CAPTAIN	Who shortly also died, for whose dear love,
# line-1.2.41	CAPTAIN	They say, she hath abjured the sight
# line-1.2.42	CAPTAIN	And company of men.
# line-1.2.43	VIOLA	O, that I served that lady,
# line-1.2.44	VIOLA	And might not be delivered to the world
# line-1.2.45	VIOLA	Till I had made mine own occasion mellow,
# line-1.2.46	VIOLA	What my estate is.
# line-1.2.47	CAPTAIN	That were hard to compass
# line-1.2.48	CAPTAIN	Because she will admit no kind of suit,
# `

# %% [markdown]
# Request and parse the HTML, and give it a shot!

# %%
raw_html = requests.get("http://floatingmedia.com/columbia/FolgerShakes/TN.html").content
tn = BeautifulSoup(raw_html, "html.parser")

# %%
lines = tn.find_all("div", attrs={"class": "div2"})
name = "NOSPEAKER"

for line in lines:
    spans = line.find_all("span", attrs = {"id" : True })
    
    for span in spans:
        name = span.find_previous("span", {"class": "speaker"})
        if name == None:
            name = "NOSPEAKER"
        else:
            name = name.string
        line_id = span["id"]
        
        if span.string == None:
            if span.find("img", attrs = {"src" : "fdt-emend-l.png"}):
                direct_c = (line.find("img", attrs = {"src" : "fdt-emend-l.png"}).next)

            elif span.find_all("img", attrs = {"src" : "fdt-emend-r.png"}):
                direct_c = (line.find("img", attrs = {"src" : "fdt-emend-r.png"}).previous)    
            print(line_id, name, direct_c)
            
        else:
            print(line_id, name, span.string)
# Out:
# line-SD 1.1.0 NOSPEAKER Enter Orsino, Duke of Illyria, Curio, and other Lords,
# line-SD 1.1.0 NOSPEAKER with
# line-SD 1.1.0 NOSPEAKER  Musicians playing.
# line-1.1.1 ORSINO If music be the food of love, play on.
# line-1.1.2 ORSINO Give me excess of it, that, surfeiting,
# line-1.1.3 ORSINO The appetite may sicken and so die.
# line-1.1.4 ORSINO That strain again! It had a dying fall.
# line-1.1.5 ORSINO O, it came o’er my ear like the sweet sound
# line-1.1.6 ORSINO That breathes upon a bank of violets,
# line-1.1.7 ORSINO Stealing and giving odor. Enough; no more.
# line-1.1.8 ORSINO ’Tis not so sweet now as it was before.
# line-1.1.9 ORSINO O spirit of love, how quick and fresh art thou,
# line-1.1.10 ORSINO That, notwithstanding thy capacity
# line-1.1.11 ORSINO Receiveth as the sea, naught enters there,
# line-1.1.12 ORSINO Of what validity and pitch soe’er,
# line-1.1.13 ORSINO But falls into abatement and low price
# line-1.1.14 ORSINO Even in a minute. So full of shapes is fancy
# line-1.1.15 ORSINO That it alone is high fantastical.
# line-1.1.16 CURIO Will you go hunt, my lord?
# line-1.1.17 ORSINO What, Curio?
# line-1.1.18 CURIO The hart.
# line-1.1.19 ORSINO Why, so I do, the noblest that I have.
# line-1.1.20 ORSINO O, when mine eyes did see Olivia first,
# line-1.1.21 ORSINO Methought she purged the air of pestilence.
# line-1.1.22 ORSINO That instant was I turned into a hart,
# line-1.1.23 ORSINO And my desires, like fell and cruel hounds,
# line-1.1.24 ORSINO E’er since pursue me.
# line-SD 1.1.24.1 ORSINO Enter Valentine.
# line-1.1.25 ORSINO How now, what news from her?
# line-1.1.26 VALENTINE So please my lord, I might not be admitted,
# line-1.1.27 VALENTINE But from her handmaid do return this answer:
# line-1.1.28 VALENTINE The element itself, till seven years’ heat,
# line-1.1.29 VALENTINE Shall not behold her face at ample view,
# line-1.1.30 VALENTINE But like a cloistress she will veilèd walk,
# line-1.1.31 VALENTINE And water once a day her chamber round
# line-1.1.32 VALENTINE With eye-offending brine—all this to season
# line-1.1.33 VALENTINE A brother’s dead love, which she would keep fresh
# line-1.1.34 VALENTINE And lasting in her sad remembrance.
# line-1.1.35 ORSINO O, she that hath a heart of that fine frame
# line-1.1.36 ORSINO To pay this debt of love but to a brother,
# line-1.1.37 ORSINO How will she love when the rich golden shaft
# line-1.1.38 ORSINO Hath killed the flock of all affections else
# line-1.1.39 ORSINO That live in her; when liver, brain, and heart,
# line-1.1.40 ORSINO These sovereign thrones, are all supplied, and filled
# line-1.1.41 ORSINO Her sweet perfections with one self king!
# line-1.1.42 ORSINO Away before me to sweet beds of flowers!
# line-1.1.43 ORSINO Love thoughts lie rich when canopied with bowers.
# line-SD 1.1.43.1 ORSINO They exit.
# line-SD 1.2.0 ORSINO Enter Viola, a Captain, and Sailors.
# line-1.2.1 VIOLA What country, friends, is this?
# line-1.2.2 CAPTAIN This is Illyria, lady.
# line-1.2.3 VIOLA And what should I do in Illyria?
# line-1.2.4 VIOLA My brother he is in Elysium.
# line-1.2.5 VIOLA Perchance he is not drowned.—What think you,
# line-1.2.6 VIOLA sailors?
# line-1.2.7 CAPTAIN It is perchance that you yourself were saved.
# line-1.2.8 VIOLA O, my poor brother! And so perchance may he be.
# line-1.2.9 CAPTAIN True, madam. And to comfort you with chance,
# line-1.2.10 CAPTAIN Assure yourself, after our ship did split,
# line-1.2.11 CAPTAIN When you and those poor number saved with you
# line-1.2.12 CAPTAIN Hung on our driving boat, I saw your brother,
# line-1.2.13 CAPTAIN Most provident in peril, bind himself
# line-1.2.14 CAPTAIN (Courage and hope both teaching him the practice)
# line-1.2.15 CAPTAIN To a strong mast that lived upon the sea,
# line-1.2.16 CAPTAIN Arion
# line-1.2.16 CAPTAIN  on the dolphin’s back,
# line-1.2.17 CAPTAIN I saw him hold acquaintance with the waves
# line-1.2.18 CAPTAIN So long as I could see.
# line-SD 1.2.19 VIOLA Arion
# line-SD 1.2.19 VIOLA Arion
# line-1.2.19 VIOLA For saying so, there’s gold.
# line-1.2.20 VIOLA Mine own escape unfoldeth to my hope,
# line-1.2.21 VIOLA Whereto thy speech serves for authority,
# line-1.2.22 VIOLA The like of him. Know’st thou this country?
# line-1.2.23 CAPTAIN Ay, madam, well, for I was bred and born
# line-1.2.24 CAPTAIN Not three hours’ travel from this very place.
# line-1.2.25 VIOLA Who governs here?
# line-1.2.26 CAPTAIN A noble duke, in nature as in name.
# line-1.2.27 VIOLA What is his name?
# line-1.2.28 CAPTAIN Orsino.
# line-1.2.29 VIOLA Orsino. I have heard my father name him.
# line-1.2.30 VIOLA He was a bachelor then.
# line-1.2.31 CAPTAIN And so is now, or was so very late;
# line-1.2.32 CAPTAIN For but a month ago I went from hence,
# line-1.2.33 CAPTAIN And then ’twas fresh in murmur (as, you know,
# line-1.2.34 CAPTAIN What great ones do the less will prattle of)
# line-1.2.35 CAPTAIN That he did seek the love of fair Olivia.
# line-1.2.36 VIOLA What’s she?
# line-1.2.37 CAPTAIN A virtuous maid, the daughter of a count
# line-1.2.38 CAPTAIN That died some twelvemonth since, then leaving her
# line-1.2.39 CAPTAIN In the protection of his son, her brother,
# line-1.2.40 CAPTAIN Who shortly also died, for whose dear love,
# line-1.2.41 CAPTAIN They say, she hath abjured the sight
# line-1.2.42 CAPTAIN And company of men.
# line-1.2.43 VIOLA O, that I served that lady,
# line-1.2.44 VIOLA And might not be delivered to the world
# line-1.2.45 VIOLA Till I had made mine own occasion mellow,
# line-1.2.46 VIOLA What my estate is.
# line-1.2.47 CAPTAIN That were hard to compass
# line-1.2.48 CAPTAIN Because she will admit no kind of suit,
# line-1.2.49 CAPTAIN No, not the Duke’s.
# line-1.2.50 VIOLA There is a fair behavior in thee, captain,
# line-1.2.51 VIOLA And though that nature with a beauteous wall
# line-1.2.52 VIOLA Doth oft close in pollution, yet of thee
# line-1.2.53 VIOLA I will believe thou hast a mind that suits
# line-1.2.54 VIOLA With this thy fair and outward character.
# line-1.2.55 VIOLA I prithee—and I’ll pay thee bounteously—
# line-1.2.56 VIOLA Conceal me what I am, and be my aid
# line-1.2.57 VIOLA For such disguise as haply shall become
# line-1.2.58 VIOLA The form of my intent. I’ll serve this duke.
# line-1.2.59 VIOLA Thou shalt present me as an eunuch to him.
# line-1.2.60 VIOLA It may be worth thy pains, for I can sing
# line-1.2.61 VIOLA And speak to him in many sorts of music
# line-1.2.62 VIOLA That will allow me very worth his service.
# line-1.2.63 VIOLA What else may hap, to time I will commit.
# line-1.2.64 VIOLA Only shape thou thy silence to my wit.
# line-1.2.65 CAPTAIN Be you his eunuch, and your mute I’ll be.
# line-1.2.66 CAPTAIN When my tongue blabs, then let mine eyes not see.
# line-1.2.67 VIOLA I thank thee. Lead me on.
# line-SD 1.2.67.1 VIOLA They exit.
# line-SD 1.3.0 VIOLA Enter Sir Toby and Maria.
# line-1.3.1 TOBY What a plague means my niece to take the death
# line-1.3.2 TOBY of her brother thus? I am sure care’s an enemy to
# line-1.3.3 TOBY life.
# line-1.3.4 MARIA By my troth, Sir Toby, you must come in earlier
# line-1.3.5 MARIA o’ nights. Your cousin, my lady, takes great exceptions
# line-1.3.6 MARIA to your ill hours.
# line-1.3.7 TOBY Why, let her except before excepted!
# line-1.3.8 MARIA Ay, but you must confine yourself within the
# line-1.3.9 MARIA modest limits of order.
# line-1.3.10 TOBY Confine? I’ll confine myself no finer than I am.
# line-1.3.11 TOBY These clothes are good enough to drink in, and so
# line-1.3.12 TOBY be these boots too. An they be not, let them hang
# line-1.3.13 TOBY themselves in their own straps!
# line-1.3.14 MARIA That quaffing and drinking will undo you. I
# line-1.3.15 MARIA heard my lady talk of it yesterday, and of a foolish
# line-1.3.16 MARIA knight that you brought in one night here to be her
# line-1.3.17 MARIA wooer.
# line-1.3.18 TOBY Who, Sir Andrew Aguecheek?
# line-1.3.19 MARIA Ay, he.
# line-1.3.20 TOBY He’s as tall a man as any ’s in Illyria.
# line-1.3.21 MARIA What’s that to th’ purpose?
# line-1.3.22 TOBY Why, he has three thousand ducats a year!
# line-1.3.23 MARIA Ay, but he’ll have but a year in all these ducats.
# line-1.3.24 MARIA He’s a very fool and a prodigal.
# line-1.3.25 TOBY Fie that you’ll say so! He plays o’ th’ viol-de-gamboys
# line-1.3.26 TOBY and speaks three or four languages word
# line-1.3.27 TOBY for word without book, and hath all the good gifts of
# line-1.3.28 TOBY nature.
# line-1.3.29 MARIA He hath indeed, almost natural, for, besides
# line-1.3.30 MARIA that he’s a fool, he’s a great quarreler, and, but that
# line-1.3.31 MARIA he hath the gift of a coward to allay the gust he hath
# line-1.3.32 MARIA in quarreling, ’tis thought among the prudent he
# line-1.3.33 MARIA would quickly have the gift of a grave.
# line-1.3.34 TOBY By this hand, they are scoundrels and substractors
# line-1.3.35 TOBY that say so of him. Who are they?
# line-1.3.36 MARIA They that add, moreover, he’s drunk nightly in
# line-1.3.37 MARIA your company.
# line-1.3.38 TOBY With drinking healths to my niece. I’ll drink to
# line-1.3.39 TOBY her as long as there is a passage in my throat and
# line-1.3.40 TOBY drink in Illyria. He’s a coward and a coistrel that
# line-1.3.41 TOBY will not drink to my niece till his brains turn o’ th’
# line-1.3.42 TOBY toe like a parish top. What, wench!
# line-1.3.42 TOBY Castiliano vulgo,
# line-1.3.43 TOBY for here comes Sir Andrew Agueface.
# line-SD 1.3.43.1 TOBY Enter Sir Andrew.
# line-1.3.44 ANDREW Sir Toby Belch! How now, Sir Toby Belch?
# line-1.3.45 TOBY Sweet Sir Andrew!
# line-SD 1.3.46 ANDREW to
# line-SD 1.3.46 ANDREW  Maria
# line-1.3.46 ANDREW Bless you, fair shrew.
# line-1.3.47 MARIA And you too, sir.
# line-1.3.48 TOBY Accost, Sir Andrew, accost!
# line-1.3.49 ANDREW What’s that?
# line-1.3.50 TOBY My niece’s chambermaid.
# line-1.3.51 None Good Mistress Accost, I desire better
# line-1.3.52 None acquaintance.
# line-1.3.53 MARIA My name is Mary, sir.
# line-1.3.54 ANDREW Good Mistress Mary Accost—
# line-1.3.55 TOBY You mistake, knight. “Accost” is front her, board
# line-1.3.56 TOBY her, woo her, assail her.
# line-1.3.57 ANDREW By my troth, I would not undertake her in
# line-1.3.58 ANDREW this company. Is that the meaning of “accost”?
# line-1.3.59 MARIA Fare you well, gentlemen.
# line-SD 1.3.59 MARIA to
# line-SD 1.3.59 MARIA  Maria
# line-1.3.60 TOBY An thou let part so, Sir Andrew, would thou
# line-1.3.61 TOBY mightst never draw sword again.
# line-1.3.62 ANDREW An you part so, mistress, I would I might
# line-1.3.63 ANDREW never draw sword again. Fair lady, do you think you
# line-1.3.64 ANDREW have fools in hand?
# line-1.3.65 MARIA Sir, I have not you by th’ hand.
# line-1.3.66 ANDREW Marry, but you shall have, and here’s my
# line-1.3.67 ANDREW hand.
# line-SD 1.3.67 ANDREW to
# line-SD 1.3.67 ANDREW  Maria
# line-SD 1.3.68 MARIA to
# line-SD 1.3.68 MARIA  Maria
# line-1.3.68 MARIA Now sir, thought is free. I
# line-1.3.69 MARIA pray you, bring your hand to th’ butt’ry bar and let
# line-1.3.70 MARIA it drink.
# line-1.3.71 ANDREW Wherefore, sweetheart? What’s your
# line-1.3.72 ANDREW metaphor?
# line-1.3.73 MARIA It’s dry, sir.
# line-1.3.74 ANDREW Why, I think so. I am not such an ass but I
# line-1.3.75 ANDREW can keep my hand dry. But what’s your jest?
# line-1.3.76 MARIA A dry jest, sir.
# line-1.3.77 ANDREW Are you full of them?
# line-1.3.78 MARIA Ay, sir, I have them at my fingers’ ends. Marry,
# line-1.3.79 MARIA now I let go your hand, I am barren.
# line-SD 1.3.79 MARIA Maria exits.
# line-1.3.80 TOBY O knight, thou lack’st a cup of canary! When did
# line-1.3.81 TOBY I see thee so put down?
# line-1.3.82 ANDREW Never in your life, I think, unless you see
# line-1.3.83 ANDREW canary put me down. Methinks sometimes I have
# line-1.3.84 ANDREW no more wit than a Christian or an ordinary man
# line-1.3.85 ANDREW has. But I am a great eater of beef, and I believe that
# line-1.3.86 ANDREW does harm to my wit.
# line-1.3.87 TOBY No question.
# line-1.3.88 ANDREW An I thought that, I’d forswear it. I’ll ride
# line-1.3.89 ANDREW home tomorrow, Sir Toby.
# line-1.3.90 TOBY Pourquoi,
# line-1.3.90 TOBY  my dear knight?
# line-1.3.91 ANDREW What is
# line-1.3.91 ANDREW “pourquoi”
# line-1.3.91 ANDREW ? Do, or not do? I would I
# line-1.3.92 ANDREW had bestowed that time in the tongues that I have in
# line-1.3.93 ANDREW fencing, dancing, and bearbaiting. O, had I but
# line-1.3.94 ANDREW followed the arts!
# line-1.3.95 TOBY Then hadst thou had an excellent head of hair.
# line-1.3.96 ANDREW Why, would that have mended my hair?
# line-1.3.97 TOBY to
# line-1.3.97 TOBY  Maria
# line-1.3.98 TOBY nature.
# line-1.3.99 ANDREW to
# line-1.3.99 ANDREW  well enough, does ’t not?
# line-1.3.100 TOBY Excellent! It hangs like flax on a distaff, and I
# line-1.3.101 TOBY hope to see a huswife take thee between her legs
# line-1.3.102 TOBY and spin it off.
# line-1.3.103 ANDREW Faith, I’ll home tomorrow, Sir Toby. Your
# line-1.3.104 ANDREW niece will not be seen, or if she be, it’s four to one
# line-1.3.105 ANDREW she’ll none of me. The Count himself here hard by
# line-1.3.106 ANDREW woos her.
# line-1.3.107 TOBY She’ll none o’ th’ Count. She’ll not match above
# line-1.3.108 TOBY her degree, neither in estate, years, nor wit. I have
# line-1.3.109 TOBY heard her swear ’t. Tut, there’s life in ’t, man.
# line-1.3.110 ANDREW I’ll stay a month longer. I am a fellow o’ th’
# line-1.3.111 ANDREW strangest mind i’ th’ world. I delight in masques
# line-1.3.112 ANDREW and revels sometimes altogether.
# line-1.3.113 TOBY Art thou good at these kickshawses, knight?
# line-1.3.114 ANDREW As any man in Illyria, whatsoever he be,
# line-1.3.115 ANDREW under the degree of my betters, and yet I will not
# line-1.3.116 ANDREW compare with an old man.
# line-1.3.117 TOBY What is thy excellence in a galliard, knight?
# line-1.3.118 ANDREW Faith, I can cut a caper.
# line-1.3.119 TOBY And I can cut the mutton to ’t.
# line-1.3.120 ANDREW And I think I have the back-trick simply as
# line-1.3.121 ANDREW strong as any man in Illyria.
# line-1.3.122 TOBY Wherefore are these things hid? Wherefore have
# line-1.3.123 TOBY these gifts a curtain before ’em? Are they like to
# line-1.3.124 TOBY take dust, like Mistress Mall’s picture? Why dost
# line-1.3.125 TOBY thou not go to church in a galliard and come home
# line-1.3.126 TOBY in a coranto? My very walk should be a jig. I would
# line-1.3.127 TOBY not so much as make water but in a sink-a-pace.
# line-1.3.128 TOBY What dost thou mean? Is it a world to hide virtues
# line-1.3.129 TOBY in? I did think, by the excellent constitution of thy
# line-1.3.130 TOBY leg, it was formed under the star of a galliard.
# line-1.3.131 ANDREW Ay, ’tis strong, and it does indifferent well in a
# line-1.3.132 ANDREW to
# line-1.3.132 ANDREW to
# line-1.3.132 ANDREW  about some
# line-1.3.133 ANDREW revels?
# line-1.3.134 TOBY What shall we do else? Were we not born under
# line-1.3.135 TOBY Taurus?
# line-1.3.136 ANDREW to
# line-1.3.136 ANDREW  sides and heart.
# line-1.3.137 TOBY No, sir, it is legs and thighs. Let me see thee
# line-1.3.138 TOBY caper.
# line-SD 1.3.138 TOBY to
# line-SD 1.3.138 TOBY  Maria
# line-1.3.138 TOBY  Ha, higher! Ha, ha,
# line-1.3.139 TOBY excellent!
# line-SD 1.3.139.1 TOBY They exit.
# line-SD 1.4.0 TOBY as
# line-SD 1.4.0 TOBY  Cesario.
# line-1.4.1 VALENTINE If the Duke continue these favors towards
# line-1.4.2 VALENTINE you, Cesario, you are like to be much advanced. He
# line-1.4.3 VALENTINE hath known you but three days, and already you
# line-1.4.4 VALENTINE are no stranger.
# line-1.4.5 VIOLA You either fear his humor or my negligence, that
# line-1.4.6 VIOLA you call in question the continuance of his love. Is
# line-1.4.7 VIOLA he inconstant, sir, in his favors?
# line-1.4.8 VALENTINE No, believe me.
# line-1.4.9 VIOLA I thank you.
# line-SD 1.4.9.1 VIOLA as
# line-SD 1.4.9.1 VIOLA  Cesario.
# line-SD 1.4.9.1 VIOLA  Curio, and Attendants.
# line-1.4.10 VIOLA Here comes the Count.
# line-1.4.11 ORSINO Who saw Cesario, ho?
# line-1.4.12 VIOLA On your attendance, my lord, here.
# line-SD 1.4.13.0 ORSINO as
# line-SD 1.4.13.0 ORSINO  Cesario.
# line-1.4.13 ORSINO Stand you awhile aloof.—Cesario,
# line-1.4.14 ORSINO Thou know’st no less but all. I have unclasped
# line-1.4.15 ORSINO To thee the book even of my secret soul.
# line-1.4.16 ORSINO Therefore, good youth, address thy gait unto her.
# line-1.4.17 ORSINO Be not denied access. Stand at her doors
# line-1.4.18 ORSINO And tell them, there thy fixèd foot shall grow
# line-1.4.19 ORSINO Till thou have audience.
# line-1.4.20 VIOLA Sure, my noble lord,
# line-1.4.21 VIOLA If she be so abandoned to her sorrow
# line-1.4.22 VIOLA As it is spoke, she never will admit me.
# line-1.4.23 ORSINO Be clamorous and leap all civil bounds
# line-1.4.24 ORSINO Rather than make unprofited return.
# line-1.4.25 VIOLA Say I do speak with her, my lord, what then?
# line-1.4.26 ORSINO O, then unfold the passion of my love.
# line-1.4.27 ORSINO Surprise her with discourse of my dear faith.
# line-1.4.28 ORSINO It shall become thee well to act my woes.
# line-1.4.29 ORSINO She will attend it better in thy youth
# line-1.4.30 ORSINO Than in a nuncio’s of more grave aspect.
# line-1.4.31 VIOLA I think not so, my lord.
# line-1.4.32 ORSINO Dear lad, believe it;
# line-1.4.33 ORSINO For they shall yet belie thy happy years
# line-1.4.34 ORSINO That say thou art a man. Diana’s lip
# line-1.4.35 ORSINO Is not more smooth and rubious, thy small pipe
# line-1.4.36 ORSINO Is as the maiden’s organ, shrill and sound,
# line-1.4.37 ORSINO And all is semblative a womans part.
# line-1.4.38 ORSINO I know thy constellation is right apt
# line-1.4.39 ORSINO For this affair.—Some four or five attend him,
# line-1.4.40 ORSINO All, if you will, for I myself am best
# line-1.4.41 ORSINO When least in company.—Prosper well in this
# line-1.4.42 ORSINO And thou shalt live as freely as thy lord,
# line-1.4.43 ORSINO To call his fortunes thine.
# line-1.4.44 VIOLA I’ll do my best
# line-1.4.45 VIOLA To woo your lady.
# line-SD 1.4.45 VIOLA as
# line-SD 1.4.45 VIOLA  Cesario.
# line-1.4.45 VIOLA  Yet a barful strife!
# line-1.4.46 VIOLA Whoe’er I woo, myself would be his wife.
# line-SD 1.4.46.1 VIOLA They exit.
# line-SD 1.5.0 VIOLA Feste
# line-SD 1.5.0 VIOLA , the Fool.
# line-1.5.1 MARIA Nay, either tell me where thou hast been, or I
# line-1.5.2 MARIA will not open my lips so wide as a bristle may enter
# line-1.5.3 MARIA in way of thy excuse. My lady will hang thee for thy
# line-1.5.4 MARIA absence.
# line-1.5.5 FOOL Let her hang me. He that is well hanged in this
# line-1.5.6 FOOL world needs to fear no colors.
# line-1.5.7 MARIA Make that good.
# line-1.5.8 FOOL He shall see none to fear.
# line-1.5.9 MARIA A good Lenten answer. I can tell thee where
# line-1.5.10 MARIA that saying was born, of “I fear no colors.”
# line-1.5.11 FOOL Where, good Mistress Mary?
# line-1.5.12 MARIA In the wars; and that may you be bold to say in
# line-1.5.13 MARIA your foolery.
# line-1.5.14 FOOL Well, God give them wisdom that have it, and
# line-1.5.15 FOOL those that are Fools, let them use their talents.
# line-1.5.16 MARIA Yet you will be hanged for being so long absent.
# line-1.5.17 MARIA Or to be turned away, is not that as good as a
# line-1.5.18 MARIA hanging to you?
# line-1.5.19 FOOL Many a good hanging prevents a bad marriage,
# line-1.5.20 FOOL and, for turning away, let summer bear it out.
# line-1.5.21 MARIA You are resolute, then?
# line-1.5.22 FOOL Not so, neither, but I am resolved on two points.
# line-1.5.23 MARIA That if one break, the other will hold, or if both
# line-1.5.24 MARIA break, your gaskins fall.
# line-1.5.25 FOOL Apt, in good faith, very apt. Well, go thy way. If Sir
# line-1.5.26 FOOL Toby would leave drinking, thou wert as witty a
# line-1.5.27 FOOL piece of Eve’s flesh as any in Illyria.
# line-1.5.28 MARIA Peace, you rogue. No more o’ that. Here comes
# line-1.5.29 MARIA my lady. Make your excuse wisely, you were best.
# line-SD 1.5.29.1 MARIA Feste
# line-SD 1.5.29.1 MARIA , the Fool.
# line-SD 1.5.29.2 MARIA Feste
# line-SD 1.5.29.2 MARIA , the Fool.
# line-SD 1.5.30 FOOL Feste
# line-1.5.30 FOOL Wit, an ’t be thy will, put me into good
# line-1.5.31 FOOL fooling! Those wits that think they have thee do very
# line-1.5.32 FOOL oft prove fools, and I that am sure I lack thee may
# line-1.5.33 FOOL pass for a wise man. For what says Quinapalus?
# line-1.5.34 FOOL “Better a witty Fool than a foolish wit.”—God bless
# line-1.5.35 FOOL thee, lady!
# line-1.5.36 OLIVIA Take the Fool away.
# line-1.5.37 FOOL Do you not hear, fellows? Take away the Lady.
# line-1.5.38 OLIVIA Go to, you’re a dry Fool. I’ll no more of you.
# line-1.5.39 OLIVIA Besides, you grow dishonest.
# line-1.5.40 FOOL Two faults, madonna, that drink and good counsel
# line-1.5.41 FOOL will amend. For give the dry Fool drink, then is
# line-1.5.42 FOOL the Fool not dry. Bid the dishonest man mend
# line-1.5.43 FOOL himself; if he mend, he is no longer dishonest; if he
# line-1.5.44 FOOL cannot, let the botcher mend him. Anything that’s
# line-1.5.45 FOOL mended is but patched; virtue that transgresses is
# line-1.5.46 FOOL but patched with sin, and sin that amends is but
# line-1.5.47 FOOL patched with virtue. If that this simple syllogism
# line-1.5.48 FOOL will serve, so; if it will not, what remedy? As there is
# line-1.5.49 FOOL no true cuckold but calamity, so beauty’s a flower.
# line-1.5.50 FOOL The Lady bade take away the Fool. Therefore, I say
# line-1.5.51 FOOL again, take her away.
# line-1.5.52 OLIVIA Sir, I bade them take away you.
# line-1.5.53 FOOL Misprision in the highest degree! Lady,
# line-1.5.53 FOOL cucullus
# line-1.5.54 FOOL non facit monachum.
# line-1.5.54 FOOL  That’s as much to say as, I
# line-1.5.55 FOOL wear not motley in my brain. Good madonna, give
# line-1.5.56 FOOL me leave to prove you a fool.
# line-1.5.57 OLIVIA Can you do it?
# line-1.5.58 FOOL Dexteriously, good madonna.
# line-1.5.59 OLIVIA Make your proof.
# line-1.5.60 FOOL I must catechize you for it, madonna. Good my
# line-1.5.61 FOOL mouse of virtue, answer me.
# line-1.5.62 OLIVIA Well, sir, for want of other idleness, I’ll bide
# line-1.5.63 OLIVIA your proof.
# line-1.5.64 FOOL Good madonna, why mourn’st thou?
# line-1.5.65 OLIVIA Good Fool, for my brother’s death.
# line-1.5.66 FOOL I think his soul is in hell, madonna.
# line-1.5.67 OLIVIA I know his soul is in heaven, Fool.
# line-1.5.68 FOOL The more fool, madonna, to mourn for your
# line-1.5.69 FOOL brother’s soul, being in heaven. Take away the fool,
# line-1.5.70 FOOL gentlemen.
# line-1.5.71 OLIVIA What think you of this Fool, Malvolio? Doth he
# line-1.5.72 OLIVIA not mend?
# line-1.5.73 MALVOLIO Yes, and shall do till the pangs of death
# line-1.5.74 MALVOLIO shake him. Infirmity, that decays the wise, doth
# line-1.5.75 MALVOLIO ever make the better Fool.
# line-1.5.76 FOOL God send you, sir, a speedy infirmity, for the
# line-1.5.77 FOOL better increasing your folly! Sir Toby will be sworn
# line-1.5.78 FOOL that I am no fox, but he will not pass his word for
# line-1.5.79 FOOL twopence that you are no fool.
# line-1.5.80 OLIVIA How say you to that, Malvolio?
# line-1.5.81 MALVOLIO I marvel your Ladyship takes delight in
# line-1.5.82 MALVOLIO such a barren rascal. I saw him put down the other
# line-1.5.83 MALVOLIO day with an ordinary fool that has no more brain
# line-1.5.84 MALVOLIO than a stone. Look you now, he’s out of his guard
# line-1.5.85 MALVOLIO already. Unless you laugh and minister occasion to
# line-1.5.86 MALVOLIO him, he is gagged. I protest I take these wise men
# line-1.5.87 MALVOLIO that crow so at these set kind of Fools no better than
# line-1.5.88 MALVOLIO the Fools’ zanies.
# line-1.5.89 OLIVIA O, you are sick of self-love, Malvolio, and taste
# line-1.5.90 OLIVIA with a distempered appetite. To be generous, guiltless,
# line-1.5.91 OLIVIA and of free disposition is to take those things
# line-1.5.92 OLIVIA for bird-bolts that you deem cannon bullets. There
# line-1.5.93 OLIVIA is no slander in an allowed Fool, though he do
# line-1.5.94 OLIVIA nothing but rail; nor no railing in a known discreet
# line-1.5.95 OLIVIA man, though he do nothing but reprove.
# line-1.5.96 FOOL Now Mercury endue thee with leasing, for thou
# line-1.5.97 FOOL speak’st well of Fools!
# line-SD 1.5.97.1 FOOL Enter Maria.
# line-1.5.98 MARIA Madam, there is at the gate a young gentleman
# line-1.5.99 MARIA much desires to speak with you.
# line-1.5.100 OLIVIA From the Count Orsino, is it?
# line-1.5.101 MARIA I know not, madam. ’Tis a fair young man, and
# line-1.5.102 MARIA well attended.
# line-1.5.103 OLIVIA Who of my people hold him in delay?
# line-1.5.104 MARIA Sir Toby, madam, your kinsman.
# line-1.5.105 OLIVIA Fetch him off, I pray you. He speaks nothing
# line-1.5.106 OLIVIA but madman. Fie on him!
# line-SD 1.5.106 OLIVIA Feste
# line-SD 1.5.106 OLIVIA , the Fool.
# line-1.5.106 OLIVIA  Go you,
# line-1.5.107 OLIVIA Malvolio. If it be a suit from the Count, I am sick,
# line-1.5.108 OLIVIA or not at home; what you will, to dismiss it.
# line-SD 1.5.108 OLIVIA
# line-SD 1.5.108 OLIVIA Malvolio
# line-SD 1.5.108 OLIVIA exits.
# line-SD 1.5.108 OLIVIA
# line-1.5.109 OLIVIA Now you see, sir, how your fooling
# line-1.5.110 OLIVIA grows old, and people dislike it.
# line-1.5.111 FOOL Thou hast spoke for us, madonna, as if thy eldest
# line-1.5.112 FOOL son should be a Fool, whose skull Jove cram with
# line-1.5.113 FOOL brains, for—here he comes—one of thy kin has a
# line-1.5.114 FOOL most weak
# line-1.5.114 FOOL pia mater.
# line-SD 1.5.114.1 FOOL Enter Sir Toby.
# line-1.5.115 OLIVIA By mine honor, half drunk!—What is he at the
# line-1.5.116 OLIVIA gate, cousin?
# line-1.5.117 TOBY A gentleman.
# line-1.5.118 OLIVIA A gentleman? What gentleman?
# line-1.5.119 TOBY ’Tis a gentleman here—a plague o’ these pickle
# line-1.5.120 TOBY herring!—How now, sot?
# line-1.5.121 FOOL Good Sir Toby.
# line-1.5.122 OLIVIA Cousin, cousin, how have you come so early by
# line-1.5.123 OLIVIA this lethargy?
# line-1.5.124 TOBY Lechery? I defy lechery. There’s one at the gate.
# line-1.5.125 OLIVIA Ay, marry, what is he?
# line-1.5.126 TOBY Let him be the devil an he will, I care not. Give
# line-1.5.127 TOBY me faith, say I. Well, it’s all one.
# line-SD 1.5.127 TOBY He exits.
# line-1.5.128 OLIVIA What’s a drunken man like, Fool?
# line-1.5.129 FOOL Like a drowned man, a fool, and a madman. One
# line-1.5.130 FOOL draught above heat makes him a fool, the second
# line-1.5.131 FOOL mads him, and a third drowns him.
# line-1.5.132 OLIVIA Go thou and seek the crowner and let him sit o’
# line-1.5.133 OLIVIA my coz, for he’s in the third degree of drink: he’s
# line-1.5.134 OLIVIA drowned. Go look after him.
# line-1.5.135 FOOL He is but mad yet, madonna, and the Fool shall
# line-1.5.136 FOOL look to the madman.
# line-SD 1.5.136 FOOL Feste
# line-SD 1.5.136 FOOL , the Fool.
# line-SD 1.5.136.1 FOOL Enter Malvolio.
# line-1.5.137 MALVOLIO Madam, yond young fellow swears he will
# line-1.5.138 MALVOLIO speak with you. I told him you were sick; he takes
# line-1.5.139 MALVOLIO on him to understand so much, and therefore
# line-1.5.140 MALVOLIO comes to speak with you. I told him you were
# line-1.5.141 MALVOLIO asleep; he seems to have a foreknowledge of that
# line-1.5.142 MALVOLIO too, and therefore comes to speak with you. What is
# line-1.5.143 MALVOLIO to be said to him, lady? He’s fortified against any
# line-1.5.144 MALVOLIO denial.
# line-1.5.145 OLIVIA Tell him he shall not speak with me.
# line-1.5.146 MALVOLIO Has been told so, and he says he’ll stand at
# line-1.5.147 MALVOLIO your door like a sheriff’s post and be the supporter
# line-1.5.148 MALVOLIO to a bench, but he’ll speak with you.
# line-1.5.149 OLIVIA What kind o’ man is he?
# line-1.5.150 MALVOLIO Why, of mankind.
# line-1.5.151 OLIVIA What manner of man?
# line-1.5.152 MALVOLIO Of very ill manner. He’ll speak with you,
# line-1.5.153 MALVOLIO will you or no.
# line-1.5.154 OLIVIA Of what personage and years is he?
# line-1.5.155 MALVOLIO Not yet old enough for a man, nor young
# line-1.5.156 MALVOLIO enough for a boy—as a squash is before ’tis a
# line-1.5.157 MALVOLIO peascod, or a codling when ’tis almost an apple. ’Tis
# line-1.5.158 MALVOLIO with him in standing water, between boy and man.
# line-1.5.159 MALVOLIO He is very well-favored, and he speaks very shrewishly.
# line-1.5.160 MALVOLIO One would think his mother’s milk were
# line-1.5.161 MALVOLIO scarce out of him.
# line-1.5.162 OLIVIA Let him approach. Call in my gentlewoman.
# line-1.5.163 MALVOLIO Gentlewoman, my lady calls.
# line-SD 1.5.163 MALVOLIO He exits.
# line-SD 1.5.163.1 MALVOLIO Enter Maria.
# line-1.5.164 OLIVIA Give me my veil. Come, throw it o’er my face.
# line-SD 1.5.164.1 OLIVIA Feste
# line-SD 1.5.164.1 OLIVIA , the Fool.
# line-1.5.165 OLIVIA We’ll once more hear Orsino’s embassy.
# line-SD 1.5.165.1 OLIVIA Feste
# line-SD 1.5.165.1 OLIVIA , the Fool.
# line-1.5.166 VIOLA The honorable lady of the house, which is she?
# line-1.5.167 OLIVIA Speak to me. I shall answer for her. Your will?
# line-1.5.168 VIOLA Most radiant, exquisite, and unmatchable
# line-1.5.169 VIOLA beauty—I pray you, tell me if this be the lady of the
# line-1.5.170 VIOLA house, for I never saw her. I would be loath to cast
# line-1.5.171 VIOLA away my speech, for, besides that it is excellently
# line-1.5.172 VIOLA well penned, I have taken great pains to con it. Good
# line-1.5.173 VIOLA beauties, let me sustain no scorn. I am very comptible
# line-1.5.174 VIOLA even to the least sinister usage.
# line-1.5.175 OLIVIA Whence came you, sir?
# line-1.5.176 VIOLA I can say little more than I have studied, and
# line-1.5.177 VIOLA that question’s out of my part. Good gentle one,
# line-1.5.178 VIOLA give me modest assurance if you be the lady of the
# line-1.5.179 VIOLA house, that I may proceed in my speech.
# line-1.5.180 OLIVIA Are you a comedian?
# line-1.5.181 VIOLA No, my profound heart. And yet by the very
# line-1.5.182 VIOLA fangs of malice I swear I am not that I play. Are
# line-1.5.183 VIOLA you the lady of the house?
# line-1.5.184 OLIVIA If I do not usurp myself, I am.
# line-1.5.185 VIOLA Most certain, if you are she, you do usurp
# line-1.5.186 VIOLA yourself, for what is yours to bestow is not yours to
# line-1.5.187 VIOLA reserve. But this is from my commission. I will on
# line-1.5.188 VIOLA with my speech in your praise and then show you
# line-1.5.189 VIOLA the heart of my message.
# line-1.5.190 OLIVIA Come to what is important in ’t. I forgive you
# line-1.5.191 OLIVIA the praise.
# line-1.5.192 VIOLA Alas, I took great pains to study it, and ’tis
# line-1.5.193 VIOLA poetical.
# line-1.5.194 OLIVIA It is the more like to be feigned. I pray you,
# line-1.5.195 OLIVIA keep it in. I heard you were saucy at my gates, and
# line-1.5.196 OLIVIA allowed your approach rather to wonder at you than
# line-1.5.197 OLIVIA to hear you. If you be not mad, begone; if you have
# line-1.5.198 OLIVIA reason, be brief. ’Tis not that time of moon with me
# line-1.5.199 OLIVIA to make one in so skipping a dialogue.
# line-1.5.200 MARIA Will you hoist sail, sir? Here lies your way.
# line-1.5.201 VIOLA No, good swabber, I am to hull here a little
# line-1.5.202 VIOLA longer.—Some mollification for your giant, sweet
# line-1.5.203 VIOLA lady.
# line-1.5.204 None Tell me your mind.
# line-1.5.205 None I am a messenger.
# line-1.5.206 OLIVIA Sure you have some hideous matter to deliver
# line-1.5.207 OLIVIA when the courtesy of it is so fearful. Speak your
# line-1.5.208 OLIVIA office.
# line-1.5.209 VIOLA It alone concerns your ear. I bring no overture
# line-1.5.210 VIOLA of war, no taxation of homage. I hold the olive in
# line-1.5.211 VIOLA my hand. My words are as full of peace as matter.
# line-1.5.212 OLIVIA Yet you began rudely. What are you? What
# line-1.5.213 OLIVIA would you?
# line-1.5.214 VIOLA The rudeness that hath appeared in me have I
# line-1.5.215 VIOLA learned from my entertainment. What I am and
# line-1.5.216 VIOLA what I would are as secret as maidenhead: to your
# line-1.5.217 VIOLA ears, divinity; to any other’s, profanation.
# line-1.5.218 OLIVIA Give us the place alone. We will hear this
# line-1.5.219 OLIVIA divinity.
# line-SD 1.5.219 OLIVIA Feste
# line-SD 1.5.219 OLIVIA , the Fool.
# line-1.5.219 OLIVIA  Now, sir, what
# line-1.5.220 OLIVIA is your text?
# line-1.5.221 VIOLA Most sweet lady—
# line-1.5.222 OLIVIA A comfortable doctrine, and much may be said
# line-1.5.223 OLIVIA of it. Where lies your text?
# line-1.5.224 VIOLA In Orsino’s bosom.
# line-1.5.225 OLIVIA In his bosom? In what chapter of his bosom?
# line-1.5.226 VIOLA To answer by the method, in the first of his heart.
# line-1.5.227 OLIVIA O, I have read it; it is heresy. Have you no more
# line-1.5.228 OLIVIA to say?
# line-1.5.229 VIOLA Good madam, let me see your face.
# line-1.5.230 OLIVIA Have you any commission from your lord to
# line-1.5.231 OLIVIA negotiate with my face? You are now out of your
# line-1.5.232 OLIVIA text. But we will draw the curtain and show you the
# line-1.5.233 OLIVIA picture.
# line-SD 1.5.233 OLIVIA Feste
# line-SD 1.5.233 OLIVIA , the Fool.
# line-1.5.233 OLIVIA  Look you, sir, such a
# line-1.5.234 OLIVIA one I was this present. Is ’t not well done?
# line-1.5.235 VIOLA Excellently done, if God did all.
# line-1.5.236 OLIVIA ’Tis in grain, sir; ’twill endure wind and
# line-1.5.237 OLIVIA weather.
# line-1.5.238 VIOLA ’Tis beauty truly blent, whose red and white
# line-1.5.239 VIOLA Nature’s own sweet and cunning hand laid on.
# line-1.5.240 VIOLA Lady, you are the cruel’st she alive
# line-1.5.241 VIOLA If you will lead these graces to the grave
# line-1.5.242 VIOLA And leave the world no copy.
# line-1.5.243 OLIVIA O, sir, I will not be so hard-hearted! I will give
# line-1.5.244 OLIVIA out divers schedules of my beauty. It shall be
# line-1.5.245 OLIVIA inventoried and every particle and utensil labeled
# line-1.5.246 OLIVIA to my will: as,
# line-1.5.246 OLIVIA item
# line-1.5.246 OLIVIA , two lips indifferent red;
# line-1.5.246 OLIVIA item
# line-1.5.246 OLIVIA ,
# line-1.5.247 OLIVIA two gray eyes with lids to them;
# line-1.5.247 OLIVIA item
# line-1.5.247 OLIVIA , one neck, one
# line-1.5.248 OLIVIA chin, and so forth. Were you sent hither to praise
# line-1.5.249 OLIVIA me?
# line-1.5.250 VIOLA I see you what you are. You are too proud.
# line-1.5.251 VIOLA But if you were the devil you are fair.
# line-1.5.252 VIOLA My lord and master loves you. O, such love
# line-1.5.253 VIOLA Could be but recompensed though you were
# line-1.5.254 VIOLA crowned
# line-1.5.255 VIOLA The nonpareil of beauty.
# line-1.5.256 OLIVIA How does he love me?
# line-1.5.257 VIOLA With adorations, fertile tears,
# line-1.5.258 VIOLA With groans that thunder love, with sighs of fire.
# line-1.5.259 OLIVIA Your lord does know my mind. I cannot love him.
# line-1.5.260 OLIVIA Yet I suppose him virtuous, know him noble,
# line-1.5.261 OLIVIA Of great estate, of fresh and stainless youth;
# line-1.5.262 OLIVIA In voices well divulged, free, learned, and valiant,
# line-1.5.263 OLIVIA And in dimension and the shape of nature
# line-1.5.264 OLIVIA A gracious person. But yet I cannot love him.
# line-1.5.265 OLIVIA He might have took his answer long ago.
# line-1.5.266 VIOLA If I did love you in my master’s flame,
# line-1.5.267 VIOLA With such a suff’ring, such a deadly life,
# line-1.5.268 VIOLA In your denial I would find no sense.
# line-1.5.269 VIOLA I would not understand it.
# line-1.5.270 OLIVIA Why, what would you?
# line-1.5.271 VIOLA Make me a willow cabin at your gate
# line-1.5.272 VIOLA And call upon my soul within the house,
# line-1.5.273 VIOLA Write loyal cantons of contemnèd love
# line-1.5.274 VIOLA And sing them loud even in the dead of night,
# line-1.5.275 VIOLA Hallow your name to the reverberate hills
# line-1.5.276 VIOLA And make the babbling gossip of the air
# line-1.5.277 VIOLA Cry out “Olivia!” O, you should not rest
# line-1.5.278 VIOLA Between the elements of air and earth
# line-1.5.279 VIOLA But you should pity me.
# line-1.5.280 OLIVIA You might do much.
# line-1.5.281 OLIVIA What is your parentage?
# line-1.5.282 VIOLA Above my fortunes, yet my state is well.
# line-1.5.283 VIOLA I am a gentleman.
# line-1.5.284 OLIVIA Get you to your lord.
# line-1.5.285 OLIVIA I cannot love him. Let him send no more—
# line-1.5.286 OLIVIA Unless perchance you come to me again
# line-1.5.287 OLIVIA To tell me how he takes it. Fare you well.
# line-1.5.288 OLIVIA I thank you for your pains. Spend this for me.
# line-SD 1.5.288.1 OLIVIA Feste
# line-SD 1.5.288.1 OLIVIA , the Fool.
# line-1.5.289 VIOLA I am no fee’d post, lady. Keep your purse.
# line-1.5.290 VIOLA My master, not myself, lacks recompense.
# line-1.5.291 VIOLA Love make his heart of flint that you shall love,
# line-1.5.292 VIOLA And let your fervor, like my master’s, be
# line-1.5.293 VIOLA Placed in contempt. Farewell, fair cruelty.
# line-SD 1.5.293 VIOLA She exits.
# line-1.5.294 OLIVIA “What is your parentage?”
# line-1.5.295 OLIVIA “Above my fortunes, yet my state is well.
# line-1.5.296 OLIVIA I am a gentleman.” I’ll be sworn thou art.
# line-1.5.297 OLIVIA Thy tongue, thy face, thy limbs, actions, and spirit
# line-1.5.298 OLIVIA Do give thee fivefold blazon. Not too fast! Soft,
# line-1.5.299 OLIVIA soft!
# line-1.5.300 OLIVIA Unless the master were the man. How now?
# line-1.5.301 OLIVIA Even so quickly may one catch the plague?
# line-1.5.302 OLIVIA Methinks I feel this youth’s perfections
# line-1.5.303 OLIVIA With an invisible and subtle stealth
# line-1.5.304 OLIVIA To creep in at mine eyes. Well, let it be.—
# line-1.5.305 OLIVIA What ho, Malvolio!
# line-SD 1.5.305.1 OLIVIA Enter Malvolio.
# line-1.5.306 MALVOLIO Here, madam, at your service.
# line-1.5.307 OLIVIA Run after that same peevish messenger,
# line-1.5.308 OLIVIA The County’s man. He left this ring behind him,
# line-1.5.309 OLIVIA Would I or not. Tell him I’ll none of it.
# line-SD 1.5.309.1 OLIVIA Feste
# line-SD 1.5.309.1 OLIVIA , the Fool.
# line-1.5.310 OLIVIA Desire him not to flatter with his lord,
# line-1.5.311 OLIVIA Nor hold him up with hopes. I am not for him.
# line-1.5.312 OLIVIA If that the youth will come this way tomorrow,
# line-1.5.313 OLIVIA I’ll give him reasons for ’t. Hie thee, Malvolio.
# line-1.5.314 MALVOLIO Madam, I will.
# line-SD 1.5.314 MALVOLIO He exits.
# line-1.5.315 OLIVIA I do I know not what, and fear to find
# line-1.5.316 OLIVIA Mine eye too great a flatterer for my mind.
# line-1.5.317 OLIVIA Fate, show thy force. Ourselves we do not owe.
# line-1.5.318 OLIVIA What is decreed must be, and be this so.
# line-SD 1.5.318.1 OLIVIA Feste
# line-SD 1.5.318.1 OLIVIA , the Fool.
# line-SD 2.1.0 OLIVIA Enter Antonio and Sebastian.
# line-2.1.1 ANTONIO Will you stay no longer? Nor will you not that
# line-2.1.2 ANTONIO I go with you?
# line-2.1.3 SEBASTIAN By your patience, no. My stars shine darkly
# line-2.1.4 SEBASTIAN over me. The malignancy of my fate might perhaps
# line-2.1.5 SEBASTIAN distemper yours. Therefore I shall crave of you your
# line-2.1.6 SEBASTIAN leave that I may bear my evils alone. It were a bad
# line-2.1.7 SEBASTIAN recompense for your love to lay any of them on you.
# line-2.1.8 ANTONIO Let me yet know of you whither you are
# line-2.1.9 ANTONIO bound.
# line-2.1.10 SEBASTIAN No, sooth, sir. My determinate voyage is
# line-2.1.11 SEBASTIAN mere extravagancy. But I perceive in you so excellent
# line-2.1.12 SEBASTIAN a touch of modesty that you will not extort
# line-2.1.13 SEBASTIAN from me what I am willing to keep in. Therefore it
# line-2.1.14 SEBASTIAN charges me in manners the rather to express myself.
# line-2.1.15 SEBASTIAN You must know of me, then, Antonio, my name
# line-2.1.16 SEBASTIAN is Sebastian, which I called Roderigo. My father was
# line-2.1.17 SEBASTIAN that Sebastian of Messaline whom I know you have
# line-2.1.18 SEBASTIAN heard of. He left behind him myself and a sister,
# line-2.1.19 SEBASTIAN both born in an hour. If the heavens had been
# line-2.1.20 SEBASTIAN pleased, would we had so ended! But you, sir,
# line-2.1.21 SEBASTIAN altered that, for some hour before you took me
# line-2.1.22 SEBASTIAN from the breach of the sea was my sister drowned.
# line-2.1.23 ANTONIO Alas the day!
# line-2.1.24 SEBASTIAN A lady, sir, though it was said she much
# line-2.1.25 SEBASTIAN resembled me, was yet of many accounted beautiful.
# line-2.1.26 SEBASTIAN But though I could not with such estimable
# line-2.1.27 SEBASTIAN wonder overfar believe that, yet thus far I will boldly
# line-2.1.28 SEBASTIAN publish her: she bore a mind that envy could not but
# line-2.1.29 SEBASTIAN call fair. She is drowned already, sir, with salt water,
# line-2.1.30 SEBASTIAN though I seem to drown her remembrance again
# line-2.1.31 SEBASTIAN with more.
# line-2.1.32 ANTONIO Pardon me, sir, your bad entertainment.
# line-2.1.33 SEBASTIAN O good Antonio, forgive me your trouble.
# line-2.1.34 ANTONIO If you will not murder me for my love, let me
# line-2.1.35 ANTONIO be your servant.
# line-2.1.36 SEBASTIAN If you will not undo what you have done—
# line-2.1.37 SEBASTIAN that is, kill him whom you have recovered—desire
# line-2.1.38 SEBASTIAN it not. Fare you well at once. My bosom is full of
# line-2.1.39 SEBASTIAN kindness, and I am yet so near the manners of my
# line-2.1.40 SEBASTIAN mother that, upon the least occasion more, mine
# line-2.1.41 SEBASTIAN eyes will tell tales of me. I am bound to the Count
# line-2.1.42 SEBASTIAN Orsino’s court. Farewell.
# line-SD 2.1.42 SEBASTIAN He exits.
# line-2.1.43 ANTONIO The gentleness of all the gods go with thee!
# line-2.1.44 ANTONIO I have many enemies in Orsino’s court,
# line-2.1.45 ANTONIO Else would I very shortly see thee there.
# line-2.1.46 ANTONIO But come what may, I do adore thee so
# line-2.1.47 ANTONIO That danger shall seem sport, and I will go.
# line-SD 2.1.47.1 ANTONIO He exits.
# line-SD 2.2.0 ANTONIO Enter Viola and Malvolio, at several doors.
# line-2.2.1 MALVOLIO Were not you even now with the Countess
# line-2.2.2 MALVOLIO Olivia?
# line-2.2.3 VIOLA Even now, sir. On a moderate pace I have since
# line-2.2.4 VIOLA arrived but hither.
# line-2.2.5 MALVOLIO She returns this ring to you, sir. You might
# line-2.2.6 MALVOLIO have saved me my pains to have taken it away
# line-2.2.7 MALVOLIO yourself. She adds, moreover, that you should put
# line-2.2.8 MALVOLIO your lord into a desperate assurance she will none
# line-2.2.9 MALVOLIO of him. And one thing more, that you be never so
# line-2.2.10 MALVOLIO hardy to come again in his affairs unless it be to
# line-2.2.11 MALVOLIO report your lord’s taking of this. Receive it so.
# line-2.2.12 VIOLA She took the ring of me. I’ll none of it.
# line-2.2.13 MALVOLIO Come, sir, you peevishly threw it to her, and
# line-2.2.14 MALVOLIO her will is it should be so returned.
# line-SD 2.2.14 MALVOLIO He
# line-SD 2.2.14 MALVOLIO  throws
# line-SD 2.2.14 MALVOLIO down the ring.
# line-SD 2.2.14 MALVOLIO
# line-2.2.15 MALVOLIO If it be worth stooping for, there it
# line-2.2.16 MALVOLIO lies in your eye; if not, be it his that finds it.
# line-SD 2.2.16.1 MALVOLIO He exits.
# line-2.2.17 VIOLA I left no ring with her. What means this lady?
# line-SD 2.2.17.1 VIOLA He
# line-SD 2.2.17.1 VIOLA down the ring.
# line-2.2.18 VIOLA Fortune forbid my outside have not charmed her!
# line-2.2.19 VIOLA She made good view of me, indeed so much
# line-2.2.20 VIOLA That methought her eyes had lost her tongue,
# line-2.2.21 VIOLA For she did speak in starts distractedly.
# line-2.2.22 VIOLA She loves me, sure! The cunning of her passion
# line-2.2.23 VIOLA Invites me in this churlish messenger.
# line-2.2.24 VIOLA None of my lord’s ring? Why, he sent her none!
# line-2.2.25 VIOLA I am the man. If it be so, as ’tis,
# line-2.2.26 VIOLA Poor lady, she were better love a dream.
# line-2.2.27 VIOLA Disguise, I see thou art a wickedness
# line-2.2.28 VIOLA Wherein the pregnant enemy does much.
# line-2.2.29 VIOLA How easy is it for the proper false
# line-2.2.30 VIOLA In women’s waxen hearts to set their forms!
# line-2.2.31 VIOLA He
# line-2.2.31 VIOLA  frailty is the cause, not we,
# line-2.2.32 VIOLA He
# line-2.2.32 VIOLA down the ring.
# line-2.2.32 VIOLA  such we be.
# line-2.2.33 VIOLA How will this fadge? My master loves her dearly,
# line-2.2.34 VIOLA And I, poor monster, fond as much on him,
# line-2.2.35 VIOLA And she, mistaken, seems to dote on me.
# line-2.2.36 VIOLA What will become of this? As I am man,
# line-2.2.37 VIOLA My state is desperate for my master’s love.
# line-2.2.38 VIOLA As I am woman (now, alas the day!),
# line-2.2.39 VIOLA What thriftless sighs shall poor Olivia breathe!
# line-2.2.40 VIOLA O Time, thou must untangle this, not I.
# line-2.2.41 VIOLA It is too hard a knot for me t’ untie.
# line-SD 2.2.41.1 VIOLA He
# line-SD 2.2.41.1 VIOLA down the ring.
# line-SD 2.3.0 VIOLA Enter Sir Toby and Sir Andrew.
# line-2.3.1 TOBY Approach, Sir Andrew. Not to be abed after
# line-2.3.2 TOBY midnight is to be up betimes, and
# line-2.3.2 TOBY “diluculo surgere,”
# line-2.3.3 TOBY thou know’st—
# line-2.3.4 ANDREW Nay, by my troth, I know not. But I know to
# line-2.3.5 ANDREW be up late is to be up late.
# line-2.3.6 TOBY A false conclusion. I hate it as an unfilled can. To
# line-2.3.7 TOBY be up after midnight and to go to bed then, is early,
# line-2.3.8 TOBY so that to go to bed after midnight is to go to bed
# line-2.3.9 TOBY betimes. Does not our lives consist of the four
# line-2.3.10 TOBY elements?
# line-2.3.11 ANDREW Faith, so they say, but I think it rather consists
# line-2.3.12 ANDREW of eating and drinking.
# line-2.3.13 TOBY Thou ’rt a scholar. Let us therefore eat and
# line-2.3.14 TOBY drink. Marian, I say, a stoup of wine!
# line-SD 2.3.14.1 TOBY Feste
# line-SD 2.3.14.1 TOBY , the Fool.
# line-2.3.15 ANDREW Here comes the Fool, i’ faith.
# line-2.3.16 FOOL How now, my hearts? Did you never see the
# line-2.3.17 FOOL picture of
# line-2.3.17 FOOL We Three
# line-2.3.17 FOOL ?
# line-2.3.18 TOBY Welcome, ass! Now let’s have a catch.
# line-2.3.19 ANDREW By my troth, the Fool has an excellent breast.
# line-2.3.20 ANDREW I had rather than forty shillings I had such a leg,
# line-2.3.21 ANDREW and so sweet a breath to sing, as the Fool has.—In
# line-2.3.22 ANDREW sooth, thou wast in very gracious fooling last night
# line-2.3.23 ANDREW when thou spok’st of Pigrogromitus of the Vapians
# line-2.3.24 ANDREW passing the equinoctial of Queubus. ’Twas very
# line-2.3.25 ANDREW good, i’ faith. I sent thee sixpence for thy leman.
# line-2.3.26 ANDREW Hadst it?
# line-2.3.27 FOOL I did impeticos thy gratillity, for Malvolio’s nose
# line-2.3.28 FOOL is no whipstock, my lady has a white hand, and the
# line-2.3.29 FOOL Myrmidons are no bottle-ale houses.
# line-2.3.30 ANDREW Excellent! Why, this is the best fooling when
# line-2.3.31 ANDREW all is done. Now, a song!
# line-SD 2.3.32 TOBY Feste
# line-SD 2.3.32 TOBY , the Fool.
# line-2.3.32 TOBY Come on, there is
# line-2.3.33 TOBY sixpence for you. Let’s have a song.
# line-SD 2.3.34 ANDREW Feste
# line-SD 2.3.34 ANDREW , the Fool.
# line-2.3.34 ANDREW There’s a testril of
# line-2.3.35 ANDREW me, too. If one knight give a—
# line-2.3.36 FOOL Would you have a love song or a song of good
# line-2.3.37 FOOL life?
# line-2.3.38 TOBY A love song, a love song.
# line-2.3.39 ANDREW Ay, ay, I care not for good life.
# line-SD 2.3.40.0 FOOL  sings
# line-2.3.40 FOOL O mistress mine, where are you roaming?
# line-2.3.41 FOOL O, stay and hear! Your truelove’s coming,
# line-2.3.42 FOOL That can sing both high and low.
# line-2.3.43 FOOL Trip no further, pretty sweeting.
# line-2.3.44 FOOL Journeys end in lovers meeting,
# line-2.3.45 FOOL Every wise man’s son doth know.
# line-2.3.46 ANDREW Excellent good, i’ faith!
# line-2.3.47 TOBY Good, good.
# line-SD 2.3.48.0 FOOL Feste
# line-2.3.48 FOOL What is love? ’Tis not hereafter.
# line-2.3.49 FOOL Present mirth hath present laughter.
# line-2.3.50 FOOL What’s to come is still unsure.
# line-2.3.51 FOOL In delay there lies no plenty,
# line-2.3.52 FOOL Then come kiss me, sweet and twenty.
# line-2.3.53 FOOL Youth’s a stuff will not endure.
# line-2.3.54 ANDREW A mellifluous voice, as I am true knight.
# line-2.3.55 TOBY A contagious breath.
# line-2.3.56 ANDREW Very sweet and contagious, i’ faith.
# line-2.3.57 TOBY To hear by the nose, it is dulcet in contagion.
# line-2.3.58 TOBY But shall we make the welkin dance indeed? Shall
# line-2.3.59 TOBY we rouse the night owl in a catch that will draw
# line-2.3.60 TOBY three souls out of one weaver? Shall we do that?
# line-2.3.61 ANDREW An you love me, let’s do ’t. I am dog at a
# line-2.3.62 ANDREW catch.
# line-2.3.63 FOOL By ’r Lady, sir, and some dogs will catch well.
# line-2.3.64 ANDREW Most certain. Let our catch be “Thou
# line-2.3.65 ANDREW Knave.”
# line-2.3.66 FOOL “Hold thy peace, thou knave,” knight? I shall be
# line-2.3.67 FOOL constrained in ’t to call thee “knave,” knight.
# line-2.3.68 ANDREW ’Tis not the first time I have constrained one
# line-2.3.69 ANDREW to call me “knave.” Begin, Fool. It begins “Hold
# line-2.3.70 ANDREW thy peace.”
# ...
# line-5.1.188 ANDREW home.
# line-5.1.189 OLIVIA Who has done this, Sir Andrew?
# line-5.1.190 ANDREW The Count’s gentleman, one Cesario. We took
# line-5.1.191 ANDREW him for a coward, but he’s the very devil
# line-5.1.192 ANDREW incardinate.
# line-5.1.193 ORSINO My gentleman Cesario?
# line-5.1.194 ANDREW ’Od’s lifelings, here he is!—You broke my
# line-5.1.195 ANDREW head for nothing, and that that I did, I was set on to
# line-5.1.196 ANDREW do ’t by Sir Toby.
# line-5.1.197 VIOLA Why do you speak to me? I never hurt you.
# line-5.1.198 VIOLA You drew your sword upon me without cause,
# line-5.1.199 VIOLA But I bespake you fair and hurt you not.
# line-5.1.200 ANDREW If a bloody coxcomb be a hurt, you have hurt
# line-5.1.201 ANDREW me. I think you set nothing by a bloody coxcomb.
# line-SD 5.1.201.1 ANDREW Feste
# line-SD 5.1.201.1 ANDREW , the Fool
# line-5.1.202 ANDREW Here comes Sir Toby halting. You shall hear
# line-5.1.203 ANDREW more. But if he had not been in drink, he would
# line-5.1.204 ANDREW have tickled you othergates than he did.
# line-5.1.205 ORSINO How now, gentleman? How is ’t with you?
# line-5.1.206 TOBY That’s all one. Has hurt me, and there’s th’ end
# line-5.1.207 TOBY on ’t.
# line-SD 5.1.207 TOBY Feste
# line-SD 5.1.207 TOBY , the Fool
# line-5.1.207 TOBY  Sot, didst see Dick Surgeon, sot?
# line-5.1.208 FOOL O, he’s drunk, Sir Toby, an hour agone; his eyes
# line-5.1.209 FOOL were set at eight i’ th’ morning.
# line-5.1.210 TOBY Then he’s a rogue and a passy-measures pavin. I
# line-5.1.211 TOBY hate a drunken rogue.
# line-5.1.212 OLIVIA Away with him! Who hath made this havoc
# line-5.1.213 OLIVIA with them?
# line-5.1.214 ANDREW I’ll help you, Sir Toby, because we’ll be
# line-5.1.215 ANDREW dressed together.
# line-5.1.216 TOBY Will you help?—an ass-head, and a coxcomb,
# line-5.1.217 TOBY and a knave, a thin-faced knave, a gull?
# line-5.1.218 OLIVIA Get him to bed, and let his hurt be looked to.
# line-SD 5.1.218.1 OLIVIA Feste
# line-SD 5.1.218.1 OLIVIA , the Fool
# line-SD 5.1.218.2 OLIVIA Enter Sebastian.
# line-5.1.219 SEBASTIAN I am sorry, madam, I have hurt your kinsman,
# line-5.1.220 SEBASTIAN But, had it been the brother of my blood,
# line-5.1.221 SEBASTIAN I must have done no less with wit and safety.
# line-5.1.222 SEBASTIAN You throw a strange regard upon me, and by that
# line-5.1.223 SEBASTIAN I do perceive it hath offended you.
# line-5.1.224 SEBASTIAN Pardon me, sweet one, even for the vows
# line-5.1.225 SEBASTIAN We made each other but so late ago.
# line-5.1.226 ORSINO One face, one voice, one habit, and two persons!
# line-5.1.227 ORSINO A natural perspective, that is and is not!
# line-5.1.228 SEBASTIAN Antonio, O, my dear Antonio!
# line-5.1.229 SEBASTIAN How have the hours racked and tortured me
# line-5.1.230 SEBASTIAN Since I have lost thee!
# line-5.1.231 ANTONIO Sebastian are you?
# line-5.1.232 SEBASTIAN Fear’st thou that, Antonio?
# line-5.1.233 ANTONIO How have you made division of yourself?
# line-5.1.234 ANTONIO An apple cleft in two is not more twin
# line-5.1.235 ANTONIO Than these two creatures. Which is Sebastian?
# line-5.1.236 OLIVIA Most wonderful!
# line-SD 5.1.237.0 SEBASTIAN Feste
# line-SD 5.1.237.0 SEBASTIAN , the Fool
# line-5.1.237 SEBASTIAN Do I stand there? I never had a brother,
# line-5.1.238 SEBASTIAN Nor can there be that deity in my nature
# line-5.1.239 SEBASTIAN Of here and everywhere. I had a sister
# line-5.1.240 SEBASTIAN Whom the blind waves and surges have devoured.
# line-5.1.241 SEBASTIAN Of charity, what kin are you to me?
# line-5.1.242 SEBASTIAN What countryman? What name? What parentage?
# line-5.1.243 VIOLA Of Messaline. Sebastian was my father.
# line-5.1.244 VIOLA Such a Sebastian was my brother too.
# line-5.1.245 VIOLA So went he suited to his watery tomb.
# line-5.1.246 VIOLA If spirits can assume both form and suit,
# line-5.1.247 VIOLA You come to fright us.
# line-5.1.248 SEBASTIAN A spirit I am indeed,
# line-5.1.249 SEBASTIAN But am in that dimension grossly clad
# line-5.1.250 SEBASTIAN Which from the womb I did participate.
# line-5.1.251 SEBASTIAN Were you a woman, as the rest goes even,
# line-5.1.252 SEBASTIAN I should my tears let fall upon your cheek
# line-5.1.253 SEBASTIAN And say “Thrice welcome, drownèd Viola.”
# line-5.1.254 VIOLA My father had a mole upon his brow.
# line-5.1.255 SEBASTIAN And so had mine.
# line-5.1.256 VIOLA And died that day when Viola from her birth
# line-5.1.257 VIOLA Had numbered thirteen years.
# line-5.1.258 SEBASTIAN O, that record is lively in my soul!
# line-5.1.259 SEBASTIAN He finishèd indeed his mortal act
# line-5.1.260 SEBASTIAN That day that made my sister thirteen years.
# line-5.1.261 VIOLA If nothing lets to make us happy both
# line-5.1.262 VIOLA But this my masculine usurped attire,
# line-5.1.263 VIOLA Do not embrace me till each circumstance
# line-5.1.264 VIOLA Of place, time, fortune, do cohere and jump
# line-5.1.265 VIOLA That I am Viola; which to confirm,
# line-5.1.266 VIOLA I’ll bring you to a captain in this town,
# line-5.1.267 VIOLA Where lie my maiden weeds; by whose gentle help
# line-5.1.268 VIOLA I was preserved to serve this noble count.
# line-5.1.269 VIOLA All the occurrence of my fortune since
# line-5.1.270 VIOLA Hath been between this lady and this lord.
# line-SD 5.1.271.0 SEBASTIAN Feste
# line-SD 5.1.271.0 SEBASTIAN , the Fool
# line-5.1.271 SEBASTIAN So comes it, lady, you have been mistook.
# line-5.1.272 SEBASTIAN But nature to her bias drew in that.
# line-5.1.273 SEBASTIAN You would have been contracted to a maid.
# line-5.1.274 SEBASTIAN Nor are you therein, by my life, deceived:
# line-5.1.275 SEBASTIAN You are betrothed both to a maid and man.
# line-SD 5.1.276.0 ORSINO Feste
# line-SD 5.1.276.0 ORSINO , the Fool
# line-5.1.276 ORSINO Be not amazed; right noble is his blood.
# line-5.1.277 ORSINO If this be so, as yet the glass seems true,
# line-5.1.278 ORSINO I shall have share in this most happy wrack.—
# line-5.1.279 ORSINO Boy, thou hast said to me a thousand times
# line-5.1.280 ORSINO Thou never shouldst love woman like to me.
# line-5.1.281 VIOLA And all those sayings will I overswear,
# line-5.1.282 VIOLA And all those swearings keep as true in soul
# line-5.1.283 VIOLA As doth that orbèd continent the fire
# line-5.1.284 VIOLA That severs day from night.
# line-5.1.285 ORSINO Give me thy hand,
# line-5.1.286 ORSINO And let me see thee in thy woman’s weeds.
# line-5.1.287 VIOLA The Captain that did bring me first on shore
# line-5.1.288 VIOLA Hath my maid’s garments. He, upon some action,
# line-5.1.289 VIOLA Is now in durance at Malvolio’s suit,
# line-5.1.290 VIOLA A gentleman and follower of my lady’s.
# line-5.1.291 OLIVIA He shall enlarge him.
# line-SD 5.1.291.1 OLIVIA Feste
# line-SD 5.1.291.1 OLIVIA , the Fool
# line-SD 5.1.291.1 OLIVIA  with a letter, and Fabian.
# line-5.1.292 OLIVIA Fetch Malvolio hither.
# line-5.1.293 OLIVIA And yet, alas, now I remember me,
# line-5.1.294 OLIVIA They say, poor gentleman, he’s much distract.
# line-5.1.295 OLIVIA A most extracting frenzy of mine own
# line-5.1.296 OLIVIA From my remembrance clearly banished his.
# line-SD 5.1.297 OLIVIA Feste
# line-SD 5.1.297 OLIVIA , the Fool
# line-SD 5.1.297 OLIVIA
# line-5.1.297 OLIVIA How does he, sirrah?
# line-5.1.298 FOOL Truly, madam, he holds Beelzebub at the stave’s
# line-5.1.299 FOOL end as well as a man in his case may do. Has here
# line-5.1.300 FOOL writ a letter to you. I should have given ’t you today
# line-5.1.301 FOOL morning. But as a madman’s epistles are no gospels,
# line-5.1.302 FOOL so it skills not much when they are delivered.
# line-5.1.303 OLIVIA Open ’t and read it.
# line-5.1.304 FOOL Look then to be well edified, when the Fool
# line-5.1.305 FOOL delivers the madman.
# line-SD 5.1.305 FOOL Feste
# line-SD 5.1.305 FOOL , the Fool
# line-5.1.305 FOOL
# line-5.1.305 FOOL By the Lord,
# line-5.1.306 FOOL madam—
# line-5.1.307 OLIVIA How now, art thou mad?
# line-5.1.308 FOOL No, madam, I do but read madness. An your
# line-5.1.309 FOOL Ladyship will have it as it ought to be, you must
# line-5.1.310 FOOL allow
# line-5.1.310 FOOL vox.
# line-5.1.311 OLIVIA Prithee, read i’ thy right wits.
# line-5.1.312 FOOL So I do, madonna. But to read his right wits is to
# line-5.1.313 FOOL read thus. Therefore, perpend, my princess, and
# line-5.1.314 FOOL give ear.
# line-SD 5.1.315 OLIVIA Feste
# line-SD 5.1.315 OLIVIA , the Fool
# line-5.1.315 OLIVIA Read it you, sirrah.
# line-SD 5.1.316 FABIAN
# line-SD 5.1.316 FABIAN reads
# line-5.1.316 FABIAN By the Lord, madam, you wrong me, and
# line-5.1.317 FABIAN the world shall know it. Though you have put me into
# line-5.1.318 FABIAN darkness and given your drunken cousin rule over
# line-5.1.319 FABIAN me, yet have I the benefit of my senses as well as your
# line-5.1.320 FABIAN Ladyship. I have your own letter that induced me to
# line-5.1.321 FABIAN the semblance I put on, with the which I doubt not but
# line-5.1.322 FABIAN to do myself much right or you much shame. Think of
# line-5.1.323 FABIAN me as you please. I leave my duty a little unthought of
# line-5.1.324 FABIAN and speak out of my injury.
# line-5.1.325 FABIAN The madly used Malvolio.
# line-5.1.326 OLIVIA Did he write this?
# line-5.1.327 FOOL Ay, madam.
# line-5.1.328 ORSINO This savors not much of distraction.
# line-5.1.329 OLIVIA See him delivered, Fabian. Bring him hither.
# line-SD 5.1.329.1 OLIVIA Feste
# line-SD 5.1.329.1 OLIVIA , the Fool
# line-SD 5.1.330 OLIVIA Feste
# line-SD 5.1.330 OLIVIA , the Fool
# line-SD 5.1.330 OLIVIA
# line-5.1.330 OLIVIA My lord, so please you, these things
# line-5.1.331 OLIVIA further thought on,
# line-5.1.332 OLIVIA To think me as well a sister as a wife,
# line-5.1.333 OLIVIA One day shall crown th’ alliance on ’t, so please
# line-5.1.334 OLIVIA you,
# line-5.1.335 OLIVIA Here at my house, and at my proper cost.
# line-5.1.336 ORSINO Madam, I am most apt t’ embrace your offer.
# line-SD 5.1.337 ORSINO Feste
# line-SD 5.1.337 ORSINO , the Fool
# line-SD 5.1.337 ORSINO
# line-5.1.337 ORSINO Your master quits you; and for your
# line-5.1.338 ORSINO service done him,
# line-5.1.339 ORSINO So much against the mettle of your sex,
# line-5.1.340 ORSINO So far beneath your soft and tender breeding,
# line-5.1.341 ORSINO And since you called me “master” for so long,
# line-5.1.342 ORSINO Here is my hand. You shall from this time be
# line-5.1.343 ORSINO Your master’s mistress.
# line-SD 5.1.344 OLIVIA Feste
# line-SD 5.1.344 OLIVIA , the Fool
# line-5.1.344 OLIVIA A sister! You are she.
# line-SD 5.1.344.1 OLIVIA Feste
# line-SD 5.1.344.1 OLIVIA , the Fool
# line-5.1.345 ORSINO Is this the madman?
# line-5.1.346 OLIVIA Ay, my lord, this same.—
# line-5.1.347 OLIVIA How now, Malvolio?
# line-5.1.348 MALVOLIO Madam, you have done me
# line-5.1.349 MALVOLIO wrong,
# line-5.1.350 MALVOLIO Notorious wrong.
# line-5.1.351 OLIVIA Have I, Malvolio? No.
# line-SD 5.1.352.0 MALVOLIO Feste
# line-SD 5.1.352.0 MALVOLIO , the Fool
# line-5.1.352 MALVOLIO Lady, you have. Pray you peruse that letter.
# line-5.1.353 MALVOLIO You must not now deny it is your hand.
# line-5.1.354 MALVOLIO Write from it if you can, in hand or phrase,
# line-5.1.355 MALVOLIO Or say ’tis not your seal, not your invention.
# line-5.1.356 MALVOLIO You can say none of this. Well, grant it then,
# line-5.1.357 MALVOLIO And tell me, in the modesty of honor,
# line-5.1.358 MALVOLIO Why you have given me such clear lights of favor?
# line-5.1.359 MALVOLIO Bade me come smiling and cross-gartered to you,
# line-5.1.360 MALVOLIO To put on yellow stockings, and to frown
# line-5.1.361 MALVOLIO Upon Sir Toby and the lighter people?
# line-5.1.362 MALVOLIO And, acting this in an obedient hope,
# line-5.1.363 MALVOLIO Why have you suffered me to be imprisoned,
# line-5.1.364 MALVOLIO Kept in a dark house, visited by the priest,
# line-5.1.365 MALVOLIO And made the most notorious geck and gull
# line-5.1.366 MALVOLIO That e’er invention played on? Tell me why.
# line-5.1.367 OLIVIA Alas, Malvolio, this is not my writing,
# line-5.1.368 OLIVIA Though I confess much like the character.
# line-5.1.369 OLIVIA But out of question, ’tis Maria’s hand.
# line-5.1.370 OLIVIA And now I do bethink me, it was she
# line-5.1.371 OLIVIA First told me thou wast mad; then cam’st in smiling,
# line-5.1.372 OLIVIA And in such forms which here were presupposed
# line-5.1.373 OLIVIA Upon thee in the letter. Prithee, be content.
# line-5.1.374 OLIVIA This practice hath most shrewdly passed upon thee.
# line-5.1.375 OLIVIA But when we know the grounds and authors of it,
# line-5.1.376 OLIVIA Thou shalt be both the plaintiff and the judge
# line-5.1.377 OLIVIA Of thine own cause.
# line-5.1.378 FABIAN Good madam, hear me speak,
# line-5.1.379 FABIAN And let no quarrel nor no brawl to come
# line-5.1.380 FABIAN Taint the condition of this present hour,
# line-5.1.381 FABIAN Which I have wondered at. In hope it shall not,
# line-5.1.382 FABIAN Most freely I confess, myself and Toby
# line-5.1.383 FABIAN Set this device against Malvolio here,
# line-5.1.384 FABIAN Upon some stubborn and uncourteous parts
# line-5.1.385 FABIAN We had conceived against him. Maria writ
# line-5.1.386 FABIAN The letter at Sir Toby’s great importance,
# line-5.1.387 FABIAN In recompense whereof he hath married her.
# line-5.1.388 FABIAN How with a sportful malice it was followed
# line-5.1.389 FABIAN May rather pluck on laughter than revenge,
# line-5.1.390 FABIAN If that the injuries be justly weighed
# line-5.1.391 FABIAN That have on both sides passed.
# line-SD 5.1.392.0 OLIVIA Feste
# line-SD 5.1.392.0 OLIVIA , the Fool
# line-5.1.392 OLIVIA Alas, poor fool, how have they baffled thee!
# line-5.1.393 FOOL Why, “some are born great, some achieve greatness,
# line-5.1.394 FOOL and some have greatness thrown upon them.”
# line-5.1.395 FOOL I was one, sir, in this interlude, one Sir Topas, sir,
# line-5.1.396 FOOL but that’s all one. “By the Lord, Fool, I am not
# line-5.1.397 FOOL mad”—but, do you remember “Madam, why laugh
# line-5.1.398 FOOL you at such a barren rascal; an you smile not, he’s
# line-5.1.399 FOOL gagged”? And thus the whirligig of time brings in
# line-5.1.400 FOOL his revenges.
# line-5.1.401 MALVOLIO I’ll be revenged on the whole pack of you!
# line-SD 5.1.401 MALVOLIO Feste
# line-SD 5.1.401 MALVOLIO , the Fool
# line-5.1.402 OLIVIA He hath been most notoriously abused.
# line-5.1.403 ORSINO Pursue him and entreat him to a peace.
# line-SD 5.1.403 ORSINO Feste
# line-SD 5.1.403 ORSINO , the Fool
# line-5.1.404 ORSINO He hath not told us of the Captain yet.
# line-5.1.405 ORSINO When that is known, and golden time convents,
# line-5.1.406 ORSINO A solemn combination shall be made
# line-5.1.407 ORSINO Of our dear souls.—Meantime, sweet sister,
# line-5.1.408 ORSINO We will not part from hence.—Cesario, come,
# line-5.1.409 ORSINO For so you shall be while you are a man.
# line-5.1.410 ORSINO But when in other habits you are seen,
# line-5.1.411 ORSINO Orsino’s mistress, and his fancy’s queen.
# line-SD 5.1.411.1 ORSINO Feste
# line-SD 5.1.411.1 ORSINO , the Fool
# line-SD 5.1.411.1 ORSINO  exit.
# line-SD 5.1.412.0 FOOL  sings
# line-5.1.412 FOOL When that I was and a little tiny boy,
# line-5.1.413 FOOL With hey, ho, the wind and the rain,
# line-5.1.414 FOOL A foolish thing was but a toy,
# line-5.1.415 FOOL For the rain it raineth every day.
# line-5.1.416 FOOL But when I came to man’s estate,
# line-5.1.417 FOOL With hey, ho, the wind and the rain,
# line-5.1.418 FOOL ’Gainst knaves and thieves men shut their gate,
# line-5.1.419 FOOL For the rain it raineth every day.
# line-5.1.420 FOOL But when I came, alas, to wive,
# line-5.1.421 FOOL With hey, ho, the wind and the rain,
# line-5.1.422 FOOL By swaggering could I never thrive,
# line-5.1.423 FOOL For the rain it raineth every day.
# line-5.1.424 FOOL But when I came unto my beds,
# line-5.1.425 FOOL With hey, ho, the wind and the rain,
# line-5.1.426 FOOL With tosspots still had drunken heads,
# line-5.1.427 FOOL For the rain it raineth every day.
# line-5.1.428 FOOL A great while ago the world begun,
# line-5.1.429 FOOL Feste
# line-5.1.429 FOOL  hey, ho, the wind and the rain,
# line-5.1.430 FOOL But that’s all one, our play is done,
# line-5.1.431 FOOL And we’ll strive to please you every day.
# line-SD 5.1.431.1 FOOL Feste
# line-SD 5.1.431.1 FOOL , the Fool
